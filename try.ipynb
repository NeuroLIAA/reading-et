# %%
import os, sys
print(os.getcwd())

sys.path.insert(0, "/home/lucy/Documents/facu/reading-et/scripts")
import scripts1
print(scripts1.__path__)
# Out:
# /home/lucy/Documents/facu/reading-et
# _NamespacePath(['/home/lucy/Documents/facu/reading-et/scripts1', '/home/lucy/Documents/facu/reading-et/scripts1', '/home/lucy/Documents/facu/reading-et/scripts1', '/home/lucy/Documents/facu/reading-et/scripts1', '/home/lucy/Documents/facu/reading-et/scripts1', '/home/lucy/Documents/facu/reading-et/scripts1'])

# %%
from scripts1.data_processing.utils import load_lines_by_screen
lines = load_lines_by_screen("stimuli/El espejo.mat")
line0 = lines[1][0]  # screen 1, line 0

print(line0["text"])
print(line0["spaces_pos"][:10])
# Out:
# Nunca me pasaron cosas raras. Me refiero a historias de fantasmas o de gente que tiene
# [ 276  360  402  514  598  696  738  850  878 1018]

# %%
lines = load_lines_by_screen("stimuli/El espejo.mat")
line0 = lines[1][0]
print(line0["text"].split()[2])
print(line0["spaces_pos"][2], line0["spaces_pos"][3])
# Out:
# pasaron
# 402 514

# %%
lines
# Out:
# {1: [{'text': 'Nunca me pasaron cosas raras. Me refiero a historias de fantasmas o de gente que tiene',
#    'spaces_pos': array([ 276,  360,  402,  514,  598,  696,  738,  850,  878, 1018, 1060,
#           1200, 1228, 1270, 1354, 1410, 1494], dtype=uint16)},
#   {'text': 'premoniciones. Nunca, o casi nunca, viví esa clase de experiencias, a no ser por esa vez. Fue una',
#    'spaces_pos': array([ 276,  486,  584,  612,  682,  780,  850,  906,  990, 1032, 1228,
#           1256, 1298, 1354, 1410, 1466, 1536, 1592, 1648], dtype=uint16)},
#   {'text': 'sola vez, pero me marcó para siempre.',
#    'spaces_pos': array([276, 346, 416, 486, 528, 612, 682, 808], dtype=uint16)},
#   {'text': 'Terminé el secundario en 1960, justo cuando los movimientos estudiantiles estaban en auge. Fui',
#    'spaces_pos': array([ 276,  388,  430,  584,  626,  710,  794,  892,  948, 1116, 1312,
#           1424, 1466, 1550, 1606], dtype=uint16)},
# ...
