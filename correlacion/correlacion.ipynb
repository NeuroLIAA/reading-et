# %% [markdown]
# ## Aux Functions

# %%
from pathlib import Path
from datetime import datetime
import json
import os
import shutil
import subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import statsmodels.formula.api as smf
from scipy.stats import spearmanr
from pandas import read_pickle

# %% [markdown]
# ### Others

# %%
def dedupe_inplace(seq):
    seen = set()
    write = 0
    for item in seq:
        if item not in seen:
            seen.add(item)
            seq[write] = item
            write += 1
    del seq[write:]

# %% [markdown]
# ### Add a simulation to the list

# %%
# add simulations to list
def add(subject=None, story=None, simulations=None):
    if simulations is None:
        raise ValueError("Simulations list is required")    
    if subject is None and story is None:
        raise ValueError("Provide at least subject or story")
    # add all simulations of a subject
    if story == None:
        _add_subject(subject, simulations)
    # add all simulations of a story
    if subject == None:
        _add_story(story, simulations)
    # add simulation for a subject and story
    if subject != None and story != None:
        sim_path = _make_simulation_path(subject, story)
        if os.path.exists(sim_path):
            simulations.append(sim_path)
        else:
            raise ValueError(f"Simulation does not exist {sim_path}")
        
    dedupe_inplace(simulations)
    return simulations
        
# add all simulations of a subject
def _add_subject(subject, simulations):
    suffix = f"{subject}.tsv"
    simulations.extend(str(p) for p in Path("simulations").rglob("*.tsv")
                       if p.name.lower().endswith(suffix))

# add all simulations of a story
def _add_story(story, simulations):
    story_dir = Path("simulations") / story
    if story_dir.is_dir():
        simulations.extend(str(p) for p in story_dir.rglob("*.tsv"))


def _make_simulation_path(subject, story):
    return f'simulations/{story}/{story}_ob1_{subject}.tsv'

# %% [markdown]
# ### Correlation

# %%
def load_pkl(file_path):
    return pd.read_pickle(file_path)

# %%
def load_all_subjects(folder):
    all_dfs = []
    for fname in os.listdir(folder):
        if fname.endswith(".pkl"):
            path = os.path.join(folder, fname)
            df = pd.read_pickle(path)
            df["subj"] = fname.replace(".pkl", "")
            all_dfs.append(df)
    return pd.concat(all_dfs, ignore_index=True)

# %%
def average_metrics_over_subjects(df):
    # metricas en las que 0 significa que no hubo fijacion -> van a NAN para que no se tengan en cuenta
    duration_metrics = ["FFD", "SFD", "FPRT", "RPD", "TFD", "RRT", "SPRT"]
    df[duration_metrics] = df[duration_metrics].replace(0, np.nan)
    # sacar las excluded
    #df = df[df["excluded"] == False]
    # hacer la media por id en oracion, id de palabra y palabra
    mean_df = df.groupby(["sentence_idx", "word_idx", "word"], as_index=False).mean(numeric_only=True)
    mean_df = mean_df.fillna(0)
    return mean_df

# %%
simulations_list = []

# %% [markdown]
# ### Graphs

# %%
def plot_correlation(df1, df2, metric="FFD"):
    """
    Visualiza la correlación entre la misma métrica en dos DataFrames.
    Ambos df deben estar alineados por (sentence_idx, word_idx).
    """
    # Unir por claves de posición
    merged = pd.merge(df1, df2, on=["sentence_idx", "word_idx"], suffixes=("_sim", "_hum"))

    x = merged[f"{metric}_sim"]
    y = merged[f"{metric}_hum"]

    # Calcular correlación
    corr_value = x.corr(y)

    # Scatterplot con línea de regresión
    plt.figure(figsize=(6,6))
    sns.regplot(x=x, y=y, scatter_kws={"alpha":0.5})
    plt.xlabel(f"{metric} simulador (OB1)")
    plt.ylabel(f"{metric} humanos")
    plt.title(f"Correlación {metric}: r = {corr_value:.3f}")
    plt.grid(alpha=0.3)
    plt.show()

    return corr_value

# %%
def plot_2d_hist_metric(
    df_sim, df_hum, metric="FFD",
    keys=("sentence_idx", "word_idx"),
    bins=25, drop_zeros=True, log_counts=True
):
    """
    Heatmap 2D (histograma conjunto) entre simulador (X) y humanos (Y).

    Parámetros
    ----------
    df_sim : DataFrame (simulador OB1)
    df_hum : DataFrame (humanos)
    metric : str, métrica a graficar (ej. "FFD")
    keys   : columnas para alinear ambos DataFrames
    bins   : número de bins del histograma
    drop_zeros : si True, descarta valores 0
    log_counts : si True, aplica log(1+count) para mejorar contraste
    """

    # 1) Unir por claves comunes
    merged = pd.merge(
        df_sim[list(keys) + [metric]].rename(columns={metric: f"{metric}_sim"}),
        df_hum[list(keys) + [metric]].rename(columns={metric: f"{metric}_hum"}),
        on=list(keys),
        how="inner"
    )

    # 2) Extraer y limpiar (X = simulación, Y = humanos)
    x = merged[f"{metric}_sim"].astype(float).values
    y = merged[f"{metric}_hum"].astype(float).values

    m = np.isfinite(x) & np.isfinite(y)
    if drop_zeros:
        m &= (x > 0) & (y > 0)

    x, y = x[m], y[m]
    if x.size == 0 or y.size == 0:
        raise ValueError("No hay datos válidos para graficar (revisá NaN/0 y la alineación).")

    # 3) Histograma 2D
    H, xedges, yedges = np.histogram2d(x, y, bins=bins)

    # 4) Escala opcional logarítmica
    Hplot = np.log1p(H) if log_counts else H

    # 5) Plot
    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    plt.figure(figsize=(6, 5))
    im = plt.imshow(Hplot.T, origin="lower", extent=extent, aspect="auto")
    plt.xlabel(f"{metric} Simulador (OB1)")
    plt.ylabel(f"{metric} Humanos")
    cbar = plt.colorbar(im)
    cbar.set_label("count (log1p)" if log_counts else "count")

    # Línea y=x como referencia
    lo = min(extent[0], extent[2]); hi = max(extent[1], extent[3])
    plt.plot([lo, hi], [lo, hi], "--", linewidth=1, color="white")

    plt.title(f"Densidad conjunta {metric}")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Setup

# %% [markdown]
# Add simulations to the simulations_list using the add function, the possible parameter combinations :
#
# - subject and story, to add a specific subject-story simulation
# - only subject, to add all simulations for that subject
# - only story, to add all simulations for that story

# %%
# add(subject = *, story = *, simulations=simulations_list)
# choose a subject and a story simulation or just a subject/story to add all its simulations
#add(subject='subject0', story='Axolotl', simulations=simulations_list)
add(subject='subject1', story='El espejo', simulations=simulations_list)
#add(subject='perfil5', story='Axolotl', simulations=simulations_list)
#add(story='cuento2', simulations=simulations_list)
#add(subject='perfil4',simulations=simulations_list)
# Out:
# ['simulations/El espejo/El espejo_ob1_subject1.tsv']

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### Make experiment folder & save files used

# %% [markdown]
# Creates a folder to save experiment information

# %%
stamp = datetime.now().strftime("%Y_%m_%d_%H%M")
experiment_folder = Path("experiments") / stamp
experiment_folder.mkdir(parents=True, exist_ok=True)
print("Created:", experiment_folder)
# Out:
# Created: experiments/2026_04_09_2247

# %%
out_path = Path(experiment_folder) / "simulations_list.json"
with out_path.open("w", encoding="utf-8") as f:
    json.dump(simulations_list, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ### Generate processed folder

# %% [markdown]
# Generates the processed folder the analysis script uses

# %% [markdown]
# Creates the folder

# %%
processed_path = "../data/processed"

if os.path.exists(processed_path):
    try:
        shutil.rmtree(processed_path)
        print(f"Folder '{processed_path}' and its contents deleted successfully.")
    except OSError as e:
        print(f"Error: {processed_path} : {e.strerror}")
else:
    print(f"Folder '{processed_path}' does not exist.")
# Out:
# Folder '../data/processed' and its contents deleted successfully.

# %%
trials_path = processed_path + '/trials'
os.makedirs(trials_path)
print(f"Folder '{trials_path}' created successfully.")
# Out:
# Folder '../data/processed/trials' created successfully.

# %% [markdown]
# Populates the folder in the correct format with the simulations in simulations_list

# %%
examples_directory = '../data/processed_examples'

# %%
def add_screens(simulation, destination_directory, stimuli_json, story):
    eye_value = 'R'
    pupil_value = -1
    df = pd.read_csv(simulation, sep="\t")

    for screen_id in range(df["text_id"].nunique()):
        df_screen = df[df["text_id"] == screen_id]
        data = []
        time_acum = 0

        # screen_index in json is 0-based
        screen_words = stimuli_json[story][screen_id]["words"]

        for _, row in df_screen.iterrows():
            index = row["fixation_counter"]
            t_start = time_acum
            duration = row["fixation_duration"]
            time_acum += duration

            word_idx = int(row["foveal_word_index"])
            x = screen_words[word_idx]["x"]
            y = screen_words[word_idx]["y"]

            data.append({
                "index": index,
                "eye": eye_value,
                "tStart": t_start,
                "tEnd": time_acum,
                "duration": duration,
                "xAvg": x,
                "yAvg": y,
                "pupilAvg": pupil_value
            })

        output_df = pd.DataFrame(data)
        output_dir = destination_directory + f"/screen_{screen_id+1}/fixations.pkl"
        print(output_dir)
        if os.path.exists(output_dir):
            os.remove(output_dir)
        output_df = pd.to_pickle(output_df, output_dir)

    print(f"Screens added to {destination_directory}")

# %%
with open("all_stimuli.json", "r", encoding="utf-8") as f:
    all_simulations_words = json.load(f)
    
for simulation in simulations_list:
    
    story = Path(simulation).stem.split("_")[0]
    subject = Path(simulation).stem.split("_")[2]
    subject_path = trials_path + '/' + subject
    print(f"Processing story {story} for subject {subject}")
    
    if not os.path.exists(processed_path):
        os.makedirs(subject_path)
    source_directory = examples_directory + '/' + story
    destination_directory = subject_path + '/' + story

    try:
        shutil.copytree(source_directory, destination_directory)
        print(f"Folder '{source_directory}' successfully copied to '{destination_directory}'")
    except FileExistsError:
        print(f"Error: Destination directory '{destination_directory}' already exists.")
    except Exception as e:
        print(f"An error occurred: {e}")
    
    add_screens(simulation, destination_directory, stimuli_json=all_simulations_words, story=story)
    print()
# Out:
# Processing story El espejo for subject subject1
# Folder '../data/processed_examples/El espejo' successfully copied to '../data/processed/trials/subject1/El espejo'
# ../data/processed/trials/subject1/El espejo/screen_1/fixations.pkl
# ../data/processed/trials/subject1/El espejo/screen_2/fixations.pkl
# ../data/processed/trials/subject1/El espejo/screen_3/fixations.pkl
# ../data/processed/trials/subject1/El espejo/screen_4/fixations.pkl
# Screens added to ../data/processed/trials/subject1/El espejo

# %% [markdown]
# ### Run analysis script

# %%
stories = []
for sim in simulations_list:
    story = sim.split('/')[1]
    print(story)
    if story not in stories:
        stories.append(story)
# Out:
# El espejo

# %%
# %%bash
# rm -rf ../results/*

# %%
for story in stories:
    subprocess.run(
        ["python3", "em_analysis.py", "--item", story, "--reprocess"],
        cwd="..",
        check=True
    )
# Out:
# Assigning fixations to words...
# Processing items in parallel:   0%|          | 0/1 [00:00<?, ?it/s]
# ----------------
# Antes
#        subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 0  subject1       1     0         0        NaN         NaN       NaN   NaN
# 1  subject1       1     0         1        2.0         2.0     175.0  21.0
# 2  subject1       1     0         2        1.0         1.0     200.0  56.0
# 3  subject1       1     0         3        3.0         3.0     225.0  42.0
# 4  subject1       1     0         4        4.0         4.0     275.0  49.0
# Después
#        subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 0  subject1       1     0         0        NaN         NaN       NaN   NaN
# 1  subject1       1     0         1        2.0         2.0     175.0  21.0
# 2  subject1       1     0         2        NaN         NaN       NaN   NaN
# 3  subject1       1     0         3        3.0         3.0     225.0  42.0
# 4  subject1       1     0         4        4.0         4.0     275.0  49.0
# ----------------
# Antes
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration      x
# 21  subject1       1     1        16       17.0        17.0     350.0  105.0
# 22  subject1       1     1        16       20.0        20.0     275.0  105.0
# 23  subject1       1     1        16       21.0        21.0     250.0  105.0
# 24  subject1       1     1        16       22.0        22.0     125.0  105.0
# 25  subject1       1     1        17       23.0        23.0     200.0   49.0
# Después
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration      x
# 21  subject1       1     1        16       17.0        17.0     350.0  105.0
# 22  subject1       1     1        16       20.0        20.0     275.0  105.0
# 23  subject1       1     1        16       21.0        21.0     250.0  105.0
# 24  subject1       1     1        16       22.0        22.0     125.0  105.0
# 25  subject1       1     1        17       23.0        23.0     200.0   49.0
# ----------------
# Antes
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 47  subject1       1     2        34       41.0        41.0     200.0  35.0
# 48  subject1       1     2        35        NaN         NaN       NaN   NaN
# 49  subject1       1     2        36       42.0        42.0     300.0  35.0
# 50  subject1       1     2        37       44.0        44.0     300.0  21.0
# 51  subject1       1     2        38       43.0        43.0     225.0  42.0
# Después
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 47  subject1       1     2        34       41.0        41.0     200.0  35.0
# 48  subject1       1     2        35        NaN         NaN       NaN   NaN
# 49  subject1       1     2        36       42.0        42.0     300.0  35.0
# 50  subject1       1     2        37       44.0        44.0     300.0  21.0
# 51  subject1       1     2        38       43.0        43.0     225.0  42.0
# ----------------
# Antes
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 54  subject1       1     3        41       46.0        46.0     225.0  56.0
# 55  subject1       1     3        42       48.0        48.0     175.0  21.0
# 56  subject1       1     3        43       47.0        47.0     400.0  77.0
# 57  subject1       1     3        43       49.0        49.0     225.0  77.0
# 58  subject1       1     3        44        NaN         NaN       NaN   NaN
# Después
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 54  subject1       1     3        41       46.0        46.0     225.0  56.0
# 55  subject1       1     3        42       48.0        48.0     175.0  21.0
# 56  subject1       1     3        43       47.0        47.0     400.0  77.0
# 57  subject1       1     3        43       49.0        49.0     225.0  77.0
# 58  subject1       1     3        44        NaN         NaN       NaN   NaN
# ----------------
# Antes
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 74  subject1       1     4        55       64.0        64.0     250.0  56.0
# 75  subject1       1     4        56       66.0        66.0     175.0  21.0
# 76  subject1       1     4        57       67.0        67.0     200.0  42.0
# 77  subject1       1     4        58        NaN         NaN       NaN   NaN
# 78  subject1       1     4        59       68.0        68.0     225.0  21.0
# Después
#         subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 74  subject1       1     4        55       64.0        64.0     250.0  56.0
# 75  subject1       1     4        56       66.0        66.0     175.0  21.0
# 76  subject1       1     4        57       67.0        67.0     200.0  42.0
# 77  subject1       1     4        58        NaN         NaN       NaN   NaN
# 78  subject1       1     4        59       68.0        68.0     225.0  21.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 104  subject1       1     5        73       92.0        92.0     325.0  56.0
# 105  subject1       1     5        74       97.0        97.0     350.0  14.0
# 106  subject1       1     5        75       93.0        93.0     325.0  63.0
# 107  subject1       1     5        75       94.0        94.0     200.0  63.0
# 108  subject1       1     5        75       95.0        95.0     300.0  63.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 104  subject1       1     5        73       92.0        92.0     325.0  56.0
# 105  subject1       1     5        74       97.0        97.0     350.0  14.0
# 106  subject1       1     5        75       93.0        93.0     325.0  63.0
# 107  subject1       1     5        75       94.0        94.0     200.0  63.0
# 108  subject1       1     5        75       95.0        95.0     300.0  63.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 124  subject1       1     6        89      111.0       111.0     200.0  14.0
# 125  subject1       1     6        90      112.0       112.0     225.0  28.0
# 126  subject1       1     6        91        NaN         NaN       NaN   NaN
# 127  subject1       1     6        92      113.0       113.0     325.0  28.0
# 128  subject1       1     6        93      114.0       114.0     250.0  63.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 124  subject1       1     6        89      111.0       111.0     200.0  14.0
# 125  subject1       1     6        90      112.0       112.0     225.0  28.0
# 126  subject1       1     6        91        NaN         NaN       NaN   NaN
# 127  subject1       1     6        92      113.0       113.0     325.0  28.0
# 128  subject1       1     6        93      114.0       114.0     250.0  63.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 147  subject1       1     7       107      134.0       134.0     200.0  21.0
# 148  subject1       1     7       108      133.0       133.0     200.0  28.0
# 149  subject1       1     7       109      132.0       132.0     250.0  49.0
# 150  subject1       1     7       109      135.0       135.0     275.0  49.0
# 151  subject1       1     7       110        NaN         NaN       NaN   NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 147  subject1       1     7       107      134.0       134.0     200.0  21.0
# 148  subject1       1     7       108        NaN         NaN       NaN   NaN
# 149  subject1       1     7       109        NaN         NaN       NaN   NaN
# 150  subject1       1     7       109      135.0       135.0     275.0  49.0
# 151  subject1       1     7       110        NaN         NaN       NaN   NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 172  subject1       1     8       126      154.0       154.0     275.0  63.0
# 173  subject1       1     8       127        NaN         NaN       NaN   NaN
# 174  subject1       1     8       128      155.0       155.0     225.0  42.0
# 175  subject1       1     8       129        NaN         NaN       NaN   NaN
# 176  subject1       1     8       130      157.0       157.0     150.0  49.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 172  subject1       1     8       126      154.0       154.0     275.0  63.0
# 173  subject1       1     8       127        NaN         NaN       NaN   NaN
# 174  subject1       1     8       128      155.0       155.0     225.0  42.0
# 175  subject1       1     8       129        NaN         NaN       NaN   NaN
# 176  subject1       1     8       130      157.0       157.0     150.0  49.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 191  subject1       1     9       143      168.0       168.0     225.0  49.0
# 192  subject1       1     9       144      169.0       169.0     200.0  56.0
# 193  subject1       1     9       145      170.0       170.0     250.0  35.0
# 194  subject1       1     9       146      176.0       176.0     225.0  21.0
# 195  subject1       1     9       147      175.0       175.0     150.0  21.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 191  subject1       1     9       143      168.0       168.0     225.0  49.0
# 192  subject1       1     9       144      169.0       169.0     200.0  56.0
# 193  subject1       1     9       145      170.0       170.0     250.0  35.0
# 194  subject1       1     9       146      176.0       176.0     225.0  21.0
# 195  subject1       1     9       147      175.0       175.0     150.0  21.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 200  subject1       1    10       149      177.0       177.0     300.0  49.0
# 201  subject1       1    10       150      178.0       178.0     250.0  49.0
# 202  subject1       1    10       151      179.0       179.0     250.0  35.0
# 203  subject1       1    10       152      180.0       180.0     250.0  42.0
# 204  subject1       1    10       153      184.0       184.0     325.0  14.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 200  subject1       1    10       149      177.0       177.0     300.0  49.0
# 201  subject1       1    10       150      178.0       178.0     250.0  49.0
# 202  subject1       1    10       151      179.0       179.0     250.0  35.0
# 203  subject1       1    10       152      180.0       180.0     250.0  42.0
# 204  subject1       1    10       153      184.0       184.0     325.0  14.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 212  subject1       1    11       159      189.0       189.0     250.0  21.0
# 213  subject1       1    11       160      188.0       188.0     250.0  63.0
# 214  subject1       1    11       161      190.0       190.0     150.0  21.0
# 215  subject1       1    11       162        NaN         NaN       NaN   NaN
# 216  subject1       1    11       163      191.0       191.0     300.0  42.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 212  subject1       1    11       159      189.0       189.0     250.0  21.0
# 213  subject1       1    11       160        NaN         NaN       NaN   NaN
# 214  subject1       1    11       161      190.0       190.0     150.0  21.0
# 215  subject1       1    11       162        NaN         NaN       NaN   NaN
# 216  subject1       1    11       163      191.0       191.0     300.0  42.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 235  subject1       1    12       179      204.0       204.0     225.0  42.0
# 236  subject1       1    12       179      223.0       223.0     175.0  63.0
# 237  subject1       1    12       180      209.0       209.0     275.0  14.0
# 238  subject1       1    12       181      206.0       206.0     275.0  21.0
# 239  subject1       1    12       181      207.0       207.0     175.0  21.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 235  subject1       1    12       179      204.0       204.0     225.0  42.0
# 236  subject1       1    12       179      223.0       223.0     175.0  63.0
# 237  subject1       1    12       180      209.0       209.0     275.0  14.0
# 238  subject1       1    12       181      206.0       206.0     275.0  21.0
# 239  subject1       1    12       181      207.0       207.0     175.0  21.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration   x
# 271  subject1       1    13       200        NaN         NaN       NaN NaN
# 272  subject1       1    13       201        NaN         NaN       NaN NaN
# 273  subject1       1    13       202        NaN         NaN       NaN NaN
# 274  subject1       1    13       203        NaN         NaN       NaN NaN
# 275  subject1       1    13       204        NaN         NaN       NaN NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration   x
# 271  subject1       1    13       200        NaN         NaN       NaN NaN
# 272  subject1       1    13       201        NaN         NaN       NaN NaN
# 273  subject1       1    13       202        NaN         NaN       NaN NaN
# 274  subject1       1    13       203        NaN         NaN       NaN NaN
# 275  subject1       1    13       204        NaN         NaN       NaN NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 288  subject1       2     0         0        NaN         NaN       NaN   NaN
# 289  subject1       2     0         1        1.0         1.0     250.0  56.0
# 290  subject1       2     0         2        2.0         2.0     275.0  70.0
# 291  subject1       2     0         3        7.0         7.0     250.0  21.0
# 292  subject1       2     0         4        3.0         3.0     250.0  70.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 288  subject1       2     0         0        NaN         NaN       NaN   NaN
# 289  subject1       2     0         1        1.0         1.0     250.0  56.0
# 290  subject1       2     0         2        2.0         2.0     275.0  70.0
# 291  subject1       2     0         3        7.0         7.0     250.0  21.0
# 292  subject1       2     0         4        3.0         3.0     250.0  70.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 306  subject1       2     1        14       18.0        18.0     250.0  49.0
# 307  subject1       2     1        15       20.0        20.0     275.0  35.0
# 308  subject1       2     1        16       19.0        19.0     225.0  56.0
# 309  subject1       2     1        17       21.0        21.0     275.0  28.0
# 310  subject1       2     1        18       22.0        22.0     225.0  49.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 306  subject1       2     1        14       18.0        18.0     250.0  49.0
# 307  subject1       2     1        15       20.0        20.0     275.0  35.0
# 308  subject1       2     1        16       19.0        19.0     225.0  56.0
# 309  subject1       2     1        17       21.0        21.0     275.0  28.0
# 310  subject1       2     1        18       22.0        22.0     225.0  49.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 320  subject1       2     2        25       32.0        32.0     200.0  42.0
# 321  subject1       2     2        26        NaN         NaN       NaN   NaN
# 322  subject1       2     2        27       33.0        33.0     350.0  42.0
# 323  subject1       2     2        28       35.0        35.0     275.0  28.0
# 324  subject1       2     2        29       34.0        34.0     300.0  42.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 320  subject1       2     2        25       32.0        32.0     200.0  42.0
# 321  subject1       2     2        26        NaN         NaN       NaN   NaN
# 322  subject1       2     2        27       33.0        33.0     350.0  42.0
# 323  subject1       2     2        28       35.0        35.0     275.0  28.0
# 324  subject1       2     2        29       34.0        34.0     300.0  42.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 344  subject1       2     3        44       51.0        51.0     225.0  21.0
# 345  subject1       2     3        45       52.0        52.0     200.0  56.0
# 346  subject1       2     3        46        NaN         NaN       NaN   NaN
# 347  subject1       2     3        47       54.0        54.0     275.0  21.0
# 348  subject1       2     3        48       53.0        53.0     200.0  42.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 344  subject1       2     3        44       51.0        51.0     225.0  21.0
# 345  subject1       2     3        45       52.0        52.0     200.0  56.0
# 346  subject1       2     3        46        NaN         NaN       NaN   NaN
# 347  subject1       2     3        47       54.0        54.0     275.0  21.0
# 348  subject1       2     3        48       53.0        53.0     200.0  42.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 361  subject1       2     4        58       69.0        69.0     250.0  21.0
# 362  subject1       2     4        59       68.0        68.0     175.0  21.0
# 363  subject1       2     4        60       65.0        65.0     400.0  56.0
# 364  subject1       2     4        60       66.0        66.0     175.0  56.0
# 365  subject1       2     4        60       67.0        67.0     250.0  56.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 361  subject1       2     4        58       69.0        69.0     250.0  21.0
# 362  subject1       2     4        59       68.0        68.0     175.0  21.0
# 363  subject1       2     4        60       65.0        65.0     400.0  56.0
# 364  subject1       2     4        60       66.0        66.0     175.0  56.0
# 365  subject1       2     4        60       67.0        67.0     250.0  56.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration   x
# 383  subject1       2     5        76        NaN         NaN       NaN NaN
# 384  subject1       2     5        77        NaN         NaN       NaN NaN
# 385  subject1       2     5        78        NaN         NaN       NaN NaN
# 386  subject1       2     5        79        NaN         NaN       NaN NaN
# 387  subject1       2     5        80        NaN         NaN       NaN NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration   x
# 383  subject1       2     5        76        NaN         NaN       NaN NaN
# 384  subject1       2     5        77        NaN         NaN       NaN NaN
# 385  subject1       2     5        78        NaN         NaN       NaN NaN
# 386  subject1       2     5        79        NaN         NaN       NaN NaN
# 387  subject1       2     5        80        NaN         NaN       NaN NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 401  subject1       2     6        94       84.0        84.0     500.0  49.0
# 402  subject1       2     6        94       86.0        86.0     375.0  49.0
# 403  subject1       2     6        94       87.0        87.0     375.0  49.0
# 404  subject1       2     6        94       89.0        89.0     300.0  49.0
# 405  subject1       2     6        95        NaN         NaN       NaN   NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 401  subject1       2     6        94       84.0        84.0     500.0  49.0
# 402  subject1       2     6        94       86.0        86.0     375.0  49.0
# 403  subject1       2     6        94       87.0        87.0     375.0  49.0
# 404  subject1       2     6        94       89.0        89.0     300.0  49.0
# 405  subject1       2     6        95        NaN         NaN       NaN   NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 434  subject1       2     7       116      109.0       109.0     175.0  70.0
# 435  subject1       2     7       116      126.0       126.0     150.0  63.0
# 436  subject1       2     7       117        NaN         NaN       NaN   NaN
# 437  subject1       2     7       118      110.0       110.0     200.0  35.0
# 438  subject1       2     7       118      127.0       127.0     375.0  49.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 434  subject1       2     7       116      109.0       109.0     175.0  70.0
# 435  subject1       2     7       116      126.0       126.0     150.0  63.0
# 436  subject1       2     7       117        NaN         NaN       NaN   NaN
# 437  subject1       2     7       118      110.0       110.0     200.0  35.0
# 438  subject1       2     7       118      127.0       127.0     375.0  49.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 473  subject1       2     8       134        NaN         NaN       NaN   NaN
# 474  subject1       2     8       135      147.0       147.0     250.0  21.0
# 475  subject1       2     8       136      148.0       148.0     400.0  49.0
# 476  subject1       2     8       136      149.0       149.0     450.0  49.0
# 477  subject1       2     8       136      151.0       151.0     300.0  49.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 473  subject1       2     8       134        NaN         NaN       NaN   NaN
# 474  subject1       2     8       135      147.0       147.0     250.0  21.0
# 475  subject1       2     8       136      148.0       148.0     400.0  49.0
# 476  subject1       2     8       136      149.0       149.0     450.0  49.0
# 477  subject1       2     8       136      151.0       151.0     300.0  49.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 501  subject1       2     9       152      172.0       172.0     275.0  77.0
# 502  subject1       2     9       153        NaN         NaN       NaN   NaN
# 503  subject1       2     9       154      173.0       173.0     200.0  70.0
# 504  subject1       2     9       154      174.0       174.0     250.0  70.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 501  subject1       2     9       152      172.0       172.0     275.0  77.0
# 502  subject1       2     9       153        NaN         NaN       NaN   NaN
# 503  subject1       2     9       154      173.0       173.0     200.0  70.0
# 504  subject1       2     9       154      174.0       174.0     250.0  70.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 505  subject1       2    10       155      175.0       175.0     225.0  49.0
# 506  subject1       2    10       156      176.0       176.0     200.0  42.0
# 507  subject1       2    10       157      179.0       179.0     150.0  28.0
# 508  subject1       2    10       158      178.0       178.0     250.0  56.0
# 509  subject1       2    10       159      177.0       177.0     300.0  70.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 505  subject1       2    10       155      175.0       175.0     225.0  49.0
# 506  subject1       2    10       156      176.0       176.0     200.0  42.0
# 507  subject1       2    10       157      179.0       179.0     150.0  28.0
# 508  subject1       2    10       158      178.0       178.0     250.0  56.0
# 509  subject1       2    10       159      177.0       177.0     300.0  70.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 524  subject1       2    11       172      192.0       192.0     275.0  35.0
# 525  subject1       2    11       173      191.0       191.0     225.0  49.0
# 526  subject1       2    11       174      193.0       193.0     225.0  21.0
# 527  subject1       2    11       175      194.0       194.0     175.0  42.0
# 528  subject1       2    11       175      196.0       196.0     275.0  42.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 524  subject1       2    11       172      192.0       192.0     275.0  35.0
# 525  subject1       2    11       173        NaN         NaN       NaN   NaN
# 526  subject1       2    11       174      193.0       193.0     225.0  21.0
# 527  subject1       2    11       175      194.0       194.0     175.0  42.0
# 528  subject1       2    11       175      196.0       196.0     275.0  42.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 549  subject1       2    12       188        NaN         NaN       NaN   NaN
# 550  subject1       2    12       189      214.0       214.0     300.0  35.0
# 551  subject1       2    12       190      216.0       216.0     300.0  42.0
# 552  subject1       2    12       191      215.0       215.0     250.0  63.0
# 553  subject1       2    12       192      217.0       217.0     375.0  63.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 549  subject1       2    12       188        NaN         NaN       NaN   NaN
# 550  subject1       2    12       189      214.0       214.0     300.0  35.0
# 551  subject1       2    12       190      216.0       216.0     300.0  42.0
# 552  subject1       2    12       191      215.0       215.0     250.0  63.0
# 553  subject1       2    12       192      217.0       217.0     375.0  63.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 566  subject1       2    13       204      228.0       228.0     300.0  21.0
# 567  subject1       2    13       204      230.0       230.0     175.0  21.0
# 568  subject1       2    13       205      227.0       227.0     175.0  49.0
# 569  subject1       2    13       206      231.0       231.0     225.0  21.0
# 570  subject1       2    13       207        NaN         NaN       NaN   NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 566  subject1       2    13       204      228.0       228.0     300.0  21.0
# 567  subject1       2    13       204      230.0       230.0     175.0  21.0
# 568  subject1       2    13       205        NaN         NaN       NaN   NaN
# 569  subject1       2    13       206      231.0       231.0     225.0  21.0
# 570  subject1       2    13       207        NaN         NaN       NaN   NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 590  subject1       3     0         0        NaN         NaN       NaN   NaN
# 591  subject1       3     0         1        2.0         2.0     425.0  21.0
# 592  subject1       3     0         2        1.0         1.0     275.0  49.0
# 593  subject1       3     0         2        3.0         3.0     275.0  49.0
# 594  subject1       3     0         3        5.0         5.0     325.0  14.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 590  subject1       3     0         0        NaN         NaN       NaN   NaN
# 591  subject1       3     0         1        2.0         2.0     425.0  21.0
# 592  subject1       3     0         2        NaN         NaN       NaN   NaN
# 593  subject1       3     0         2        3.0         3.0     275.0  49.0
# 594  subject1       3     0         3        5.0         5.0     325.0  14.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 603  subject1       3     1        11       15.0        15.0     225.0  49.0
# 604  subject1       3     1        12       14.0        14.0     325.0  14.0
# 605  subject1       3     1        13       11.0        11.0     375.0  84.0
# 606  subject1       3     1        13       12.0        12.0     200.0  84.0
# 607  subject1       3     1        13       13.0        13.0     200.0  84.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 603  subject1       3     1        11       15.0        15.0     225.0  49.0
# 604  subject1       3     1        12       14.0        14.0     325.0  14.0
# 605  subject1       3     1        13       11.0        11.0     375.0  84.0
# 606  subject1       3     1        13       12.0        12.0     200.0  84.0
# 607  subject1       3     1        13       13.0        13.0     200.0  84.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 625  subject1       3     2        28        NaN         NaN       NaN   NaN
# 626  subject1       3     2        29       29.0        29.0     225.0  63.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 625  subject1       3     2        28        NaN         NaN       NaN   NaN
# 626  subject1       3     2        29       29.0        29.0     225.0  63.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 627  subject1       3     3        30       31.0        31.0     200.0  28.0
# 628  subject1       3     3        31       30.0        30.0     200.0  49.0
# 629  subject1       3     3        31       32.0        32.0     325.0  49.0
# 630  subject1       3     3        31       33.0        33.0     225.0  49.0
# 631  subject1       3     3        31       35.0        35.0     350.0  49.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 627  subject1       3     3        30       31.0        31.0     200.0  28.0
# 628  subject1       3     3        31        NaN         NaN       NaN   NaN
# 629  subject1       3     3        31       32.0        32.0     325.0  49.0
# 630  subject1       3     3        31       33.0        33.0     225.0  49.0
# 631  subject1       3     3        31       35.0        35.0     350.0  49.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 651  subject1       3     4        49       51.0        51.0     350.0  49.0
# 652  subject1       3     4        49       53.0        53.0     300.0  49.0
# 653  subject1       3     4        49       54.0        54.0     350.0  49.0
# 654  subject1       3     4        49       56.0        56.0     400.0  49.0
# 655  subject1       3     4        50       55.0        55.0     300.0  21.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 651  subject1       3     4        49       51.0        51.0     350.0  49.0
# 652  subject1       3     4        49       53.0        53.0     300.0  49.0
# 653  subject1       3     4        49       54.0        54.0     350.0  49.0
# 654  subject1       3     4        49       56.0        56.0     400.0  49.0
# 655  subject1       3     4        50       55.0        55.0     300.0  21.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 674  subject1       3     5        64        NaN         NaN       NaN   NaN
# 675  subject1       3     5        65       73.0        73.0     300.0  56.0
# 676  subject1       3     5        66       77.0        77.0     125.0  35.0
# 677  subject1       3     5        67       76.0        76.0     150.0  21.0
# 678  subject1       3     5        68       74.0        74.0     275.0  70.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 674  subject1       3     5        64        NaN         NaN       NaN   NaN
# 675  subject1       3     5        65       73.0        73.0     300.0  56.0
# 676  subject1       3     5        66       77.0        77.0     125.0  35.0
# 677  subject1       3     5        67       76.0        76.0     150.0  21.0
# 678  subject1       3     5        68       74.0        74.0     275.0  70.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 695  subject1       3     6        80        NaN         NaN       NaN   NaN
# 696  subject1       3     6        81       89.0        89.0     200.0  42.0
# 697  subject1       3     6        81       90.0        90.0     200.0  42.0
# 698  subject1       3     6        82       92.0        92.0     375.0  21.0
# 699  subject1       3     6        83       91.0        91.0     150.0  28.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 695  subject1       3     6        80        NaN         NaN       NaN   NaN
# 696  subject1       3     6        81       89.0        89.0     200.0  42.0
# 697  subject1       3     6        81       90.0        90.0     200.0  42.0
# 698  subject1       3     6        82       92.0        92.0     375.0  21.0
# 699  subject1       3     6        83       91.0        91.0     150.0  28.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 720  subject1       3     7       100      110.0       110.0     325.0  35.0
# 721  subject1       3     7       101      112.0       112.0     200.0  21.0
# 722  subject1       3     7       102      114.0       114.0     225.0  49.0
# 723  subject1       3     7       103      113.0       113.0     250.0  84.0
# 724  subject1       3     7       103      115.0       115.0     250.0  84.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 720  subject1       3     7       100      110.0       110.0     325.0  35.0
# 721  subject1       3     7       101      112.0       112.0     200.0  21.0
# 722  subject1       3     7       102      114.0       114.0     225.0  49.0
# 723  subject1       3     7       103      113.0       113.0     250.0  84.0
# 724  subject1       3     7       103      115.0       115.0     250.0  84.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 726  subject1       3     8       104      119.0       119.0     275.0  42.0
# 727  subject1       3     8       105      118.0       118.0     200.0  28.0
# 728  subject1       3     8       106      117.0       117.0     275.0  56.0
# 729  subject1       3     8       107      120.0       120.0     150.0  21.0
# 730  subject1       3     8       108      122.0       122.0     275.0  35.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 726  subject1       3     8       104      119.0       119.0     275.0  42.0
# 727  subject1       3     8       105        NaN         NaN       NaN   NaN
# 728  subject1       3     8       106        NaN         NaN       NaN   NaN
# 729  subject1       3     8       107      120.0       120.0     150.0  21.0
# 730  subject1       3     8       108      122.0       122.0     275.0  35.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 745  subject1       3     9       123      132.0       132.0     175.0  21.0
# 746  subject1       3     9       124      134.0       134.0     250.0  35.0
# 747  subject1       3     9       125      133.0       133.0     275.0  84.0
# 748  subject1       3     9       126      135.0       135.0     275.0  35.0
# 749  subject1       3     9       127      137.0       137.0     150.0  28.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 745  subject1       3     9       123      132.0       132.0     175.0  21.0
# 746  subject1       3     9       124      134.0       134.0     250.0  35.0
# 747  subject1       3     9       125      133.0       133.0     275.0  84.0
# 748  subject1       3     9       126      135.0       135.0     275.0  35.0
# 749  subject1       3     9       127      137.0       137.0     150.0  28.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 766  subject1       3    10       143      148.0       148.0     175.0  28.0
# 767  subject1       3    10       144      150.0       150.0     400.0  21.0
# 768  subject1       3    10       145      149.0       149.0     325.0  77.0
# 769  subject1       3    10       145      151.0       151.0     425.0  77.0
# 770  subject1       3    10       145      152.0       152.0     300.0  77.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 766  subject1       3    10       143      148.0       148.0     175.0  28.0
# 767  subject1       3    10       144      150.0       150.0     400.0  21.0
# 768  subject1       3    10       145      149.0       149.0     325.0  77.0
# 769  subject1       3    10       145      151.0       151.0     425.0  77.0
# 770  subject1       3    10       145      152.0       152.0     300.0  77.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 784  subject1       3    11       156      163.0       163.0     300.0  21.0
# 785  subject1       3    11       157      165.0       165.0     175.0  42.0
# 786  subject1       3    11       158      164.0       164.0     350.0  70.0
# 787  subject1       3    11       159      167.0       167.0     250.0  21.0
# 788  subject1       3    11       160      166.0       166.0     350.0  77.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 784  subject1       3    11       156      163.0       163.0     300.0  21.0
# 785  subject1       3    11       157      165.0       165.0     175.0  42.0
# 786  subject1       3    11       158      164.0       164.0     350.0  70.0
# 787  subject1       3    11       159      167.0       167.0     250.0  21.0
# 788  subject1       3    11       160      166.0       166.0     350.0  77.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 806  subject1       3    12       174      180.0       180.0     200.0  35.0
# 807  subject1       3    12       175        NaN         NaN       NaN   NaN
# 808  subject1       3    12       176      182.0       182.0     200.0  35.0
# 809  subject1       3    12       177      181.0       181.0     200.0  63.0
# 810  subject1       3    12       178      183.0       183.0     275.0  28.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 806  subject1       3    12       174      180.0       180.0     200.0  35.0
# 807  subject1       3    12       175        NaN         NaN       NaN   NaN
# 808  subject1       3    12       176      182.0       182.0     200.0  35.0
# 809  subject1       3    12       177      181.0       181.0     200.0  63.0
# 810  subject1       3    12       178      183.0       183.0     275.0  28.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 824  subject1       3    13       190      193.0       193.0     175.0  35.0
# 825  subject1       3    13       191      196.0       196.0     350.0  21.0
# 826  subject1       3    13       192      194.0       194.0     275.0  49.0
# 827  subject1       3    13       192      195.0       195.0     150.0  49.0
# 828  subject1       3    13       193        NaN         NaN       NaN   NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 824  subject1       3    13       190      193.0       193.0     175.0  35.0
# 825  subject1       3    13       191      196.0       196.0     350.0  21.0
# 826  subject1       3    13       192      194.0       194.0     275.0  49.0
# 827  subject1       3    13       192      195.0       195.0     150.0  49.0
# 828  subject1       3    13       193        NaN         NaN       NaN   NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 849  subject1       4     0         0        NaN         NaN       NaN   NaN
# 850  subject1       4     0         1        NaN         NaN       NaN   NaN
# 851  subject1       4     0         2        1.0         1.0     200.0  21.0
# 852  subject1       4     0         3        2.0         2.0     400.0  49.0
# 853  subject1       4     0         3        4.0         4.0     375.0  49.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 849  subject1       4     0         0        NaN         NaN       NaN   NaN
# 850  subject1       4     0         1        NaN         NaN       NaN   NaN
# 851  subject1       4     0         2        1.0         1.0     200.0  21.0
# 852  subject1       4     0         3        2.0         2.0     400.0  49.0
# 853  subject1       4     0         3        4.0         4.0     375.0  49.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 876  subject1       4     1        21       23.0        23.0     125.0  21.0
# 877  subject1       4     1        21       24.0        24.0     225.0  21.0
# 878  subject1       4     1        22       22.0        22.0     275.0  70.0
# 879  subject1       4     1        23       26.0        26.0     300.0  63.0
# 880  subject1       4     1        24        NaN         NaN       NaN   NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 876  subject1       4     1        21       23.0        23.0     125.0  21.0
# 877  subject1       4     1        21       24.0        24.0     225.0  21.0
# 878  subject1       4     1        22        NaN         NaN       NaN   NaN
# 879  subject1       4     1        23       26.0        26.0     300.0  63.0
# 880  subject1       4     1        24        NaN         NaN       NaN   NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 883  subject1       4     2        26       29.0        29.0     200.0  42.0
# 884  subject1       4     2        27        NaN         NaN       NaN   NaN
# 885  subject1       4     2        28       31.0        31.0     225.0  21.0
# 886  subject1       4     2        29       30.0        30.0     325.0  63.0
# 887  subject1       4     2        30       32.0        32.0     250.0  35.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 883  subject1       4     2        26       29.0        29.0     200.0  42.0
# 884  subject1       4     2        27        NaN         NaN       NaN   NaN
# 885  subject1       4     2        28       31.0        31.0     225.0  21.0
# 886  subject1       4     2        29       30.0        30.0     325.0  63.0
# 887  subject1       4     2        30       32.0        32.0     250.0  35.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 907  subject1       4     3        46       47.0        47.0     225.0  49.0
# 908  subject1       4     3        47       50.0        50.0     150.0  21.0
# 909  subject1       4     3        48       49.0        49.0     275.0  28.0
# 910  subject1       4     3        49       48.0        48.0     275.0  63.0
# 911  subject1       4     3        50       51.0        51.0     250.0  56.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 907  subject1       4     3        46       47.0        47.0     225.0  49.0
# 908  subject1       4     3        47       50.0        50.0     150.0  21.0
# 909  subject1       4     3        48       49.0        49.0     275.0  28.0
# 910  subject1       4     3        49       48.0        48.0     275.0  63.0
# 911  subject1       4     3        50       51.0        51.0     250.0  56.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 928  subject1       4     4        64       64.0        64.0     275.0  49.0
# 929  subject1       4     4        65        NaN         NaN       NaN   NaN
# 930  subject1       4     4        66       66.0        66.0     275.0  28.0
# 931  subject1       4     4        67       65.0        65.0     225.0  63.0
# 932  subject1       4     4        68       67.0        67.0     175.0  21.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 928  subject1       4     4        64       64.0        64.0     275.0  49.0
# 929  subject1       4     4        65        NaN         NaN       NaN   NaN
# 930  subject1       4     4        66       66.0        66.0     275.0  28.0
# 931  subject1       4     4        67       65.0        65.0     225.0  63.0
# 932  subject1       4     4        68       67.0        67.0     175.0  21.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 949  subject1       4     5        81       81.0        81.0     200.0  35.0
# 950  subject1       4     5        82       83.0        83.0     200.0  21.0
# 951  subject1       4     5        83       85.0        85.0     350.0  35.0
# 952  subject1       4     5        84       84.0        84.0     250.0  56.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 949  subject1       4     5        81       81.0        81.0     200.0  35.0
# 950  subject1       4     5        82       83.0        83.0     200.0  21.0
# 951  subject1       4     5        83       85.0        85.0     350.0  35.0
# 952  subject1       4     5        84       84.0        84.0     250.0  56.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 953  subject1       4     6        85       86.0        86.0     275.0  42.0
# 954  subject1       4     6        86        NaN         NaN       NaN   NaN
# 955  subject1       4     6        87       87.0        87.0     400.0  14.0
# 956  subject1       4     6        88        NaN         NaN       NaN   NaN
# 957  subject1       4     6        89       88.0        88.0     250.0  56.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 953  subject1       4     6        85       86.0        86.0     275.0  42.0
# 954  subject1       4     6        86        NaN         NaN       NaN   NaN
# 955  subject1       4     6        87       87.0        87.0     400.0  14.0
# 956  subject1       4     6        88        NaN         NaN       NaN   NaN
# 957  subject1       4     6        89       88.0        88.0     250.0  56.0
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 975  subject1       4     7       104        NaN         NaN       NaN   NaN
# 976  subject1       4     7       105      103.0       103.0     200.0  42.0
# 977  subject1       4     7       106      104.0       104.0     175.0  56.0
# 978  subject1       4     7       107      105.0       105.0     225.0  42.0
# 979  subject1       4     7       108        NaN         NaN       NaN   NaN
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 975  subject1       4     7       104        NaN         NaN       NaN   NaN
# 976  subject1       4     7       105      103.0       103.0     200.0  42.0
# 977  subject1       4     7       106      104.0       104.0     175.0  56.0
# 978  subject1       4     7       107      105.0       105.0     225.0  42.0
# 979  subject1       4     7       108        NaN         NaN       NaN   NaN
# ----------------
# Antes
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 984  subject1       4     8       112      112.0       112.0     225.0  35.0
# 985  subject1       4     8       113      111.0       111.0     250.0  21.0
# 986  subject1       4     8       114      110.0       110.0     250.0  70.0
# 987  subject1       4     8       115      113.0       113.0     225.0  35.0
# 988  subject1       4     8       116      116.0       116.0     350.0  21.0
# Después
#          subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 984  subject1       4     8       112      112.0       112.0     225.0  35.0
# 985  subject1       4     8       113        NaN         NaN       NaN   NaN
# 986  subject1       4     8       114        NaN         NaN       NaN   NaN
# 987  subject1       4     8       115      113.0       113.0     225.0  35.0
# 988  subject1       4     8       116      116.0       116.0     350.0  21.0
# ----------------
# Antes
#           subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 1004  subject1       4     9       130      129.0       129.0     200.0  21.0
# 1005  subject1       4     9       131      132.0       132.0     300.0  35.0
# Después
#           subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 1004  subject1       4     9       130      129.0       129.0     200.0  21.0
# 1005  subject1       4     9       131      132.0       132.0     300.0  35.0
# ----------------
# Antes
#           subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 1006  subject1       4    10       132      131.0       131.0     225.0  21.0
# 1007  subject1       4    10       133      130.0       130.0     225.0  42.0
# 1008  subject1       4    10       134        NaN         NaN       NaN   NaN
# Después
#           subj  screen  line  word_pos  trial_fix  screen_fix  duration     x
# 1006  subject1       4    10       132      131.0       131.0     225.0  21.0
# 1007  subject1       4    10       133        NaN         NaN       NaN   NaN
# 1008  subject1       4    10       134        NaN         NaN       NaN   NaN
# Processing items in parallel: 100%|██████████| 1/1 [00:02<00:00,  2.60s/it]
# Processing items in parallel:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting eye-tracking measures from trials...
# Processing items in parallel: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# Analysing eye-tracking measures...
#            subjs  words  words_excluded  fix  fix_excluded  regressions  skips  out_of_bounds  return_sweeps
# El espejo      1    628             155  650           178          230    278              0             14
# Total          1    628             155  650           178          230    278              0             14
# Figure(640x480)
# Figure(1400x1200)
# Figure(1400x1200)
# [INFO] MLM salteado: se necesitan >=2 sujetos e >=2 ítems (hay subj=1, item=1).
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages
#
# R[write to console]: 2:
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages
#
# R[write to console]: 3:
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages
#
# R[write to console]: 4:
# R[write to console]: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
# R[write to console]:
#
# R[write to console]:  libraries ‘/usr/local/lib/R/site-library’, ‘/usr/lib/R/site-library’ contain no packages

# %%
source_directory = "../results"
destination_directory = experiment_folder / "results"

try:
    shutil.copytree(source_directory, destination_directory)
    print(f"Folder '{source_directory}' successfully copied to '{destination_directory}'")
except FileExistsError:
    print(f"Error: Destination directory '{destination_directory}' already exists.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Folder '../results' successfully copied to 'experiments/2026_04_09_2247/results'

# %% [markdown]
# ## Correlations

# %%
# measures to use
measures_path_1 = Path('results_og_all_El espejo', 'measures')
measures_path_2 = Path(f'{experiment_folder}/results', 'measures')
# save results
measures_correlation_path = Path(experiment_folder, 'measures_correlation')
# measures to analyze
measures = ['FFD', 'FPRT', 'TFD', 'SFD', 'SPRT', 'RRT']
# number of bins
n_bins = 10

# %% [markdown]
# ### Code

# %%
items_1 = list(measures_path_1.iterdir())
items_2 = list(measures_path_2.iterdir())
item_subj_1 = {item.name: list(item.iterdir()) for item in items_1}
item_subj_2 = {item.name: list(item.iterdir()) for item in items_2}
common_items = set(item_subj_1.keys()) & set(item_subj_2.keys())
measures_correlation_path.mkdir(parents=True, exist_ok=True)

# %%
def binarize_measure(subj, measure):
    measure_mask = subj[measure] > 0
    subj = subj.astype({measure: np.float32})
    subj.loc[:, measure] = pd.qcut(subj[measure][measure_mask], n_bins, labels=False,
                                   duplicates='drop')
    subj.loc[:, measure] = subj[measure].fillna(0)
    subj.loc[:, measure] = subj[measure].astype(np.int32)

def binarize_subjects_measures(subjects, measures):
    binarized_subjects = []
    for name, subj in subjects:
        subj = subj[~subj['excluded']]
        for measure in measures:
            binarize_measure(subj, measure)
        binarized_subjects.append((name, subj))
    return binarized_subjects

def compute_correlation_matrices(subjects_1, subjects_2, all_measures):
    correlation_matrices = []

    for measure in all_measures:
        correlation_matrix = np.zeros((len(subjects_1), len(subjects_2)))
        for i, (name1, subj1) in enumerate(subjects_1):
            for j, (name2, subj2) in enumerate(subjects_2):
                corr = spearmanr(subj1[measure], subj2[measure])[0]
                correlation_matrix[i, j] = 0 if np.isnan(corr) else corr
        correlation_matrices.append(correlation_matrix)

    return correlation_matrices

def plot_correlation_matrices(correlation_matrices, all_measures, title, min_val=0.0, max_val=1.0, filename='global_avg'): 
    fig, axes = plt.subplots(2, 3, figsize=(9, 6), sharex=True, sharey=True)
    cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])
    
    for i, measure in enumerate(all_measures):
        sns.heatmap(correlation_matrices[i], ax=axes[i // 3, i % 3], cmap='coolwarm', center=0,
                    vmin=min_val, vmax=max_val, cbar=(i == 0), cbar_ax=cbar_ax if i == 0 else None)
        axes[i // 3, i % 3].set_title(measure)
        axes[i // 3, i % 3].tick_params(axis='y', rotation=0)
        axes[i // 3, i % 3].tick_params(axis='x', rotation=0)
    
    if title:
        fig.suptitle(title + f' - {n_bins} bins')
    plt.subplots_adjust(right=0.9)
    
    fig.savefig(measures_correlation_path / f'{filename}.png', dpi=300)
    
def plot_individual_correlation_matrices(correlation_matrices, all_measures, title=None,
                                         min_val=0.0, max_val=1.0, filename_prefix='plot'):

    for i, measure in enumerate(all_measures):
        fig, ax = plt.subplots(figsize=(6, 5))

        sns.heatmap(
            correlation_matrices[i],
            ax=ax,
            cmap='coolwarm',
            center=0,
            vmin=min_val,
            vmax=max_val,
            cbar=True
        )

        ax.set_title(measure if title is None else f'{title} - {measure}')
        ax.tick_params(axis='y', rotation=0)
        ax.tick_params(axis='x', rotation=0)
        ax.set_xlabel('Dataset 2 subjects')
        ax.set_ylabel('Dataset 1 subjects')

        plt.tight_layout()

        safe_measure = measure.replace(" ", "_").replace("/", "_")
        safe_prefix = filename_prefix.replace(" ", "_").replace("/", "_")

        fig.savefig(
            measures_correlation_path / f'{safe_prefix}_{safe_measure}.png',
            dpi=300
        )

        plt.show()
        plt.close(fig)

# %%
items_correlation_matrices = {}
items_subject_names = {}
for item in common_items:
    subjects_1 = [(subj_path.stem, read_pickle(subj_path)) for subj_path in item_subj_1[item]]
    subjects_2 = [(subj_path.stem, read_pickle(subj_path)) for subj_path in item_subj_2[item]]
    binarized_subjects_1 = binarize_subjects_measures(subjects_1, measures)
    binarized_subjects_2 = binarize_subjects_measures(subjects_2, measures)
    correlation_matrices = compute_correlation_matrices(binarized_subjects_1, binarized_subjects_2, measures)
    items_correlation_matrices[item] = correlation_matrices
    items_subject_names[item] = {
        "subjects_1": [name for name, _ in binarized_subjects_1],
        "subjects_2": [name for name, _ in binarized_subjects_2],
    }

# %%
rows = []

for item in items_correlation_matrices:
    correlation_matrices = items_correlation_matrices[item]

    subj_names_1 = items_subject_names[item]["subjects_1"]
    subj_names_2 = items_subject_names[item]["subjects_2"]

    for m_idx, measure in enumerate(measures):
        mat = correlation_matrices[m_idx]

        for i, name1 in enumerate(subj_names_1):
            for j, name2 in enumerate(subj_names_2):
                rows.append({
                    "item": item,
                    "subject_1": name1,
                    "subject_2": name2,
                    "measure": measure,
                    "correlation": mat[i, j]
                })

df_corr = pd.DataFrame(rows)

# %%
mapping_rows = []

for item in items_subject_names:
    for i, name in enumerate(items_subject_names[item]["subjects_1"]):
        mapping_rows.append({
            "item": item,
            "dataset": "dataset_1",
            "index": i,
            "subject_name": name
        })

    for j, name in enumerate(items_subject_names[item]["subjects_2"]):
        mapping_rows.append({
            "item": item,
            "dataset": "dataset_2",
            "index": j,
            "subject_name": name
        })

mapping_df = pd.DataFrame(mapping_rows)

# %%
df_corr.to_csv(measures_correlation_path / 'correlation_results.csv', index=False)
mapping_df.to_csv(measures_correlation_path / 'subject_mapping.csv', index=False)

# %% [markdown]
# ### Final correlations

# %%
df_corr[df_corr['measure'] == 'FFD'].sort_values(by=['correlation'], ascending=False)
# Out:
#          item subject_1 subject_2 measure  correlation
# 8   El espejo   sub-109  subject1     FFD     0.342996
# 5   El espejo   sub-079  subject1     FFD     0.333995
# 40  El espejo   sub-034  subject1     FFD     0.330970
# 44  El espejo   sub-096  subject1     FFD     0.329299
# 18  El espejo   sub-044  subject1     FFD     0.326612
# 55  El espejo   sub-068  subject1     FFD     0.321743
# 28  El espejo   sub-091  subject1     FFD     0.316981
# 4   El espejo   sub-097  subject1     FFD     0.314654
# 15  El espejo   sub-052  subject1     FFD     0.307055
# 13  El espejo   sub-095  subject1     FFD     0.295995
# 52  El espejo   sub-098  subject1     FFD     0.292912
# 16  El espejo   sub-094  subject1     FFD     0.291765
# 29  El espejo   sub-083  subject1     FFD     0.291329
# 6   El espejo   sub-028  subject1     FFD     0.290713
# 50  El espejo   sub-003  subject1     FFD     0.290314
# 54  El espejo   sub-013  subject1     FFD     0.287213
# 20  El espejo   sub-041  subject1     FFD     0.281002
# 38  El espejo   sub-064  subject1     FFD     0.280426
# 12  El espejo   sub-001  subject1     FFD     0.279241
# 51  El espejo   sub-107  subject1     FFD     0.277568
# 2   El espejo   sub-078  subject1     FFD     0.277125
# 35  El espejo   sub-060  subject1     FFD     0.261382
# 30  El espejo   sub-065  subject1     FFD     0.259454
# 3   El espejo   sub-046  subject1     FFD     0.254512
# 48  El espejo   sub-101  subject1     FFD     0.254446
# 36  El espejo   sub-103  subject1     FFD     0.252186
# 27  El espejo   sub-087  subject1     FFD     0.249539
# 45  El espejo   sub-027  subject1     FFD     0.246804
# 41  El espejo   sub-002  subject1     FFD     0.238084
# 46  El espejo   sub-006  subject1     FFD     0.237426
# 24  El espejo   sub-058  subject1     FFD     0.237002
# 22  El espejo   sub-016  subject1     FFD     0.224471
# 7   El espejo   sub-089  subject1     FFD     0.223435
# 26  El espejo   sub-048  subject1     FFD     0.223411
# 34  El espejo   sub-075  subject1     FFD     0.221859
# 23  El espejo   sub-112  subject1     FFD     0.217358
# 37  El espejo   sub-105  subject1     FFD     0.216787
# 32  El espejo   sub-039  subject1     FFD     0.216203
# 33  El espejo   sub-053  subject1     FFD     0.214658
# 0   El espejo   sub-067  subject1     FFD     0.213343
# 47  El espejo   sub-066  subject1     FFD     0.209637
# 21  El espejo   sub-024  subject1     FFD     0.205763
# 49  El espejo   sub-042  subject1     FFD     0.203388
# 10  El espejo   sub-111  subject1     FFD     0.196506
# 25  El espejo   sub-018  subject1     FFD     0.184651
# 39  El espejo   sub-010  subject1     FFD     0.183368
# 11  El espejo   sub-073  subject1     FFD     0.182476
# 42  El espejo   sub-085  subject1     FFD     0.179120
# 9   El espejo   sub-070  subject1     FFD     0.173377
# 17  El espejo   sub-088  subject1     FFD     0.157279
# 19  El espejo   sub-009  subject1     FFD     0.146152
# 1   El espejo   sub-054  subject1     FFD     0.144848
# 14  El espejo   sub-012  subject1     FFD     0.143944
# 31  El espejo   sub-077  subject1     FFD     0.143245
# 53  El espejo   sub-086  subject1     FFD     0.134075
# 43  El espejo   sub-021  subject1     FFD     0.119913

# %% [markdown]
# ### All plots

# %%
for item in items_correlation_matrices:
    correlation_matrices = items_correlation_matrices[item]

    plot_correlation_matrices(
        correlation_matrices,
        measures,
        title=item,
        min_val=0.0,
        max_val=0.4,
        filename=f"{item}"
    )

# %% [markdown]
# ### Individual plots

# %%
for item in items_correlation_matrices:
    correlation_matrices = items_correlation_matrices[item]
    safe_item = item.replace(" ", "_").replace("/", "_")

    plot_individual_correlation_matrices(
        correlation_matrices,
        measures,
        title=item,
        min_val=0.0,
        max_val=0.4,
        filename_prefix=safe_item
    )

# %% [markdown]
# ### Mumber mappings

# %%
mapping_df
# Out:
#          item    dataset  index subject_name
# 0   El espejo  dataset_1      0      sub-067
# 1   El espejo  dataset_1      1      sub-054
# 2   El espejo  dataset_1      2      sub-078
# 3   El espejo  dataset_1      3      sub-046
# 4   El espejo  dataset_1      4      sub-097
# 5   El espejo  dataset_1      5      sub-079
# 6   El espejo  dataset_1      6      sub-028
# 7   El espejo  dataset_1      7      sub-089
# 8   El espejo  dataset_1      8      sub-109
# 9   El espejo  dataset_1      9      sub-070
# 10  El espejo  dataset_1     10      sub-111
# 11  El espejo  dataset_1     11      sub-073
# 12  El espejo  dataset_1     12      sub-001
# 13  El espejo  dataset_1     13      sub-095
# 14  El espejo  dataset_1     14      sub-012
# 15  El espejo  dataset_1     15      sub-052
# 16  El espejo  dataset_1     16      sub-094
# 17  El espejo  dataset_1     17      sub-088
# 18  El espejo  dataset_1     18      sub-044
# 19  El espejo  dataset_1     19      sub-009
# 20  El espejo  dataset_1     20      sub-041
# 21  El espejo  dataset_1     21      sub-024
# 22  El espejo  dataset_1     22      sub-016
# 23  El espejo  dataset_1     23      sub-112
# 24  El espejo  dataset_1     24      sub-058
# 25  El espejo  dataset_1     25      sub-018
# 26  El espejo  dataset_1     26      sub-048
# 27  El espejo  dataset_1     27      sub-087
# 28  El espejo  dataset_1     28      sub-091
# 29  El espejo  dataset_1     29      sub-083
# 30  El espejo  dataset_1     30      sub-065
# 31  El espejo  dataset_1     31      sub-077
# 32  El espejo  dataset_1     32      sub-039
# 33  El espejo  dataset_1     33      sub-053
# 34  El espejo  dataset_1     34      sub-075
# 35  El espejo  dataset_1     35      sub-060
# 36  El espejo  dataset_1     36      sub-103
# 37  El espejo  dataset_1     37      sub-105
# 38  El espejo  dataset_1     38      sub-064
# 39  El espejo  dataset_1     39      sub-010
# 40  El espejo  dataset_1     40      sub-034
# 41  El espejo  dataset_1     41      sub-002
# 42  El espejo  dataset_1     42      sub-085
# 43  El espejo  dataset_1     43      sub-021
# 44  El espejo  dataset_1     44      sub-096
# 45  El espejo  dataset_1     45      sub-027
# 46  El espejo  dataset_1     46      sub-006
# 47  El espejo  dataset_1     47      sub-066
# 48  El espejo  dataset_1     48      sub-101
# 49  El espejo  dataset_1     49      sub-042
# 50  El espejo  dataset_1     50      sub-003
# 51  El espejo  dataset_1     51      sub-107
# 52  El espejo  dataset_1     52      sub-098
# 53  El espejo  dataset_1     53      sub-086
# 54  El espejo  dataset_1     54      sub-013
# 55  El espejo  dataset_1     55      sub-068
# 56  El espejo  dataset_2      0     subject1
