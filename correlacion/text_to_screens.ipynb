# %% [markdown]
# ## Aux Functions

# %%
from pathlib import Path
from datetime import datetime
import json
import os
import shutil
import subprocess
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import seaborn as sns
import statsmodels.formula.api as smf

# %%
from scipy.io import loadmat

item = "Axolotl"  # change to your stimuli name (without .mat)
mat = loadmat(f"../data/stimuli/{item}.mat", simplify_cells=True)

lines = mat["lines"]  # list of line dicts
print("Number of lines:", len(lines))

# Show all lines with their spaces_pos
for i, line in enumerate(lines):
    text = line["text"]
    spaces_pos = line["spaces_pos"]
    screen = line["screen"]
    print(f"\nLine {i} (screen {screen})")
    print("text:", text)
    print("spaces_pos:", spaces_pos)
# Out:
# Number of lines: 232
#
# Line 0 (screen 1)
# text:    Hubo un tiempo en que yo pensaba mucho en los
# spaces_pos: [144 159 173 187 257 299 397 440 496 538 650 735 777 833]
#
# Line 1 (screen 1)
# text: axolotl. Iba a verlos al acuario del Jardín des
# spaces_pos: [144 271 327 355 454 496 608 664 763 819]
#
# Line 2 (screen 1)
# text: Plantes y me quedaba horas mirándolos, observando su
# spaces_pos: [144 257 285 327 440 524 692 847 889]
#
# Line 3 (screen 1)
# text: inmovilidad, sus oscuros movimientos. Ahora soy un
# spaces_pos: [144 327 383 496 678 763 819 861]
#
# Line 4 (screen 1)
# text: axolotl.
# spaces_pos: [144 271]
#
# Line 5 (screen 1)
# text:    El azar me llevó hasta ellos una mañana de
# spaces_pos: [144 159 173 187 229 299 341 425 510 594 650 749 791]
#
# Line 6 (screen 1)
# text: primavera en que París abría su cola de pavo real
# spaces_pos: [144 285 327 383 468 552 594 664 706 777 847]
#
# Line 7 (screen 1)
# text: después de la lenta invernada. Bajé por el bulevar de
# spaces_pos: [144 257 299 341 425 580 650 706 749 861 903]
#
# Line 8 (screen 1)
# text: Port Royal, tomé St. Marcel y L'Hôpital, vi los
# spaces_pos: [144 215 313 383 440 538 566 721 763 819]
#
# Line 9 (screen 1)
# text: verdes entre tanto gris y me acordé de los leones.
# spaces_pos: [144 243 327 411 482 510 552 650 692 749 861]
#
# Line 10 (screen 2)
# text: Era amigo de los leones y las panteras, pero nunca
# spaces_pos: [144 201 285 327 383 482 510 566 706 777 861]
#
# Line 11 (screen 2)
# text: había entrado en el húmedo y oscuro edificio de los
# spaces_pos: [144 229 341 383 425 524 552 650 777 819 875]
#
# Line 12 (screen 2)
# text: acuarios. Dejé mi bicicleta contra las rejas y fui a
# spaces_pos: [144 285 355 397 538 636 692 777 805 861 889]
#
# Line 13 (screen 2)
# text: ver los tulipanes. Los leones estaban feos y tristes
# spaces_pos: [144 201 257 411 468 566 678 749 777 889]
#
# Line 14 (screen 2)
# text: y mi pantera dormía. Opté por los acuarios, soslayé
# spaces_pos: [144 173 215 327 440 510 566 622 763 875]
#
# Line 15 (screen 2)
# text: peces vulgares hasta dar inesperadamente con los
# spaces_pos: [144 229 355 440 496 721 777 833]
#
# Line 16 (screen 2)
# text: axolotl. Me quedé una hora mirándolos, y salí incapaz
# spaces_pos: [144 271 313 397 454 524 692 721 791 903]
#
# Line 17 (screen 2)
# text: de otra cosa.
# spaces_pos: [144 187 257 341]
#
# Line 18 (screen 2)
# text:    En la biblioteca Saint-Geneviève consulté un
# spaces_pos: [144 159 173 187 229 271 425 650 777 819]
#
# Line 19 (screen 2)
# text: diccionario y supe que los axolotl son formas
# spaces_pos: [144 313 341 411 468 524 636 692 791]
#
# Line 20 (screen 3)
# text: larvales, provistas de branquias, de una especie de
# spaces_pos: [144 285 425 468 622 664 721 833 875]
#
# Line 21 (screen 3)
# text: batracios del género amblistoma. Que eran mexicanos
# spaces_pos: [144 285 341 440 608 664 735 875]
#
# Line 22 (screen 3)
# text: lo sabía ya por ellos mismos, por sus pequeños
# spaces_pos: [144 187 271 313 369 454 566 622 678 805]
#
# Line 23 (screen 3)
# text: rostros rosados aztecas y el cartel en lo alto del
# spaces_pos: [144 257 369 482 510 552 650 692 735 805 861]
#
# Line 24 (screen 3)
# text: acuario. Leí que se han encontrado ejemplares en
# spaces_pos: [144 271 327 383 425 482 636 791 833]
#
# Line 25 (screen 3)
# text: África capaces de vivir en tierra durante los
# spaces_pos: [144 243 355 397 482 524 622 735 791]
#
# Line 26 (screen 3)
# text: períodos de sequía, y que continúan su vida en el
# spaces_pos: [144 271 313 425 454 510 650 692 763 805 847]
#
# Line 27 (screen 3)
# text: agua al llegar la estación de las lluvias. Encontré
# spaces_pos: [144 215 257 355 397 524 566 622 749 875]
#
# Line 28 (screen 3)
# text: su nombre español, ajolote, la mención de que son
# spaces_pos: [144 187 285 411 538 580 692 735 791 847]
#
# Line 29 (screen 3)
# text: comestibles y que su aceite se usaba (se diría que no
# spaces_pos: [144 313 341 397 440 538 580 664 721 805 861 903]
#
# Line 30 (screen 4)
# text: se usa más) como el de hígado de bacalao.
# spaces_pos: [144 187 243 313 383 425 468 566 608 735]
#
# Line 31 (screen 4)
# text:    No quise consultar obras especializadas, pero
# spaces_pos: [144 159 173 187 229 313 454 538 763 833]
#
# Line 32 (screen 4)
# text: volví al día siguiente al Jardin des Plantes. Empecé
# spaces_pos: [144 229 271 327 468 510 608 664 791 889]
#
# Line 33 (screen 4)
# text: a ir todas las mañanas, a veces de mañana y de tarde.
# spaces_pos: [144 173 215 299 355 482 510 594 636 735 763 805 903]
#
# Line 34 (screen 4)
# text: El guardián de los acuarios sonreía perplejo al
# spaces_pos: [144 187 313 355 411 538 650 777 819]
#
# Line 35 (screen 4)
# text: recibir el billete. Me apoyaba en la barra de hierro
# spaces_pos: [144 257 299 425 468 580 622 664 749 791 889]
#
# Line 36 (screen 4)
# text: que bordea los acuarios y me ponía a mirarlos. No hay
# spaces_pos: [144 201 299 355 482 510 552 636 664 805 847 903]
#
# Line 37 (screen 4)
# text: nada de extraño en esto porque desde un primer
# spaces_pos: [144 215 257 369 411 482 580 664 706 805]
#
# Line 38 (screen 4)
# text: momento comprendí que estábamos vinculados, que algo
# spaces_pos: [144 257 397 454 594 763 819 889]
#
# Line 39 (screen 4)
# text: infinitamente perdido y distante seguía sin embargo
# spaces_pos: [144 341 454 482 608 706 763 875]
#
# Line 40 (screen 5)
# text: uniéndonos. Me había bastado detenerme aquella
# spaces_pos: [144 313 355 440 552 692 805]
#
# Line 41 (screen 5)
# text: primera mañana ante el cristal donde unas burbujas
# spaces_pos: [144 257 355 425 468 580 664 735 861]
#
# Line 42 (screen 5)
# text: corrían en el agua. Los axolotl se amontonaban en el
# spaces_pos: [144 257 299 341 425 482 594 636 805 847 889]
#
# Line 43 (screen 5)
# text: mezquino y angosto (sólo yo puedo saber cuán angosto
# spaces_pos: [144 271 299 411 496 538 622 706 777 889]
#
# Line 44 (screen 5)
# text: y mezquino) piso de piedra y musgo del acuario. Había
# spaces_pos: [144 173 313 383 425 524 552 636 692 819 903]
#
# Line 45 (screen 5)
# text: nueve ejemplares y la mayoría apoyaba la cabeza
# spaces_pos: [144 229 383 411 454 566 678 721 819]
#
# Line 46 (screen 5)
# text: contra el cristal, mirando con sus ojos de oro a los
# spaces_pos: [144 243 285 411 524 580 636 706 749 805 833 889]
#
# Line 47 (screen 5)
# text: que se acercaban. Turbado, casi avergonzado, sentí
# spaces_pos: [144 201 243 397 524 594 777 861]
#
# Line 48 (screen 5)
# text: como una impudicia asomarme a esas figuras
# spaces_pos: [144 215 271 411 538 566 636 749]
#
# Line 49 (screen 5)
# text: silenciosas e inmóviles aglomeradas en el fondo del
# spaces_pos: [144 313 341 482 650 692 735 819 875]
#
# Line 50 (screen 6)
# text: acuario. Aislé mentalmente una situada a la derecha y
# spaces_pos: [144 271 355 524 580 692 721 763 875 903]
#
# Line 51 (screen 6)
# text: algo separada de las otras para estudiarla mejor. Vi
# spaces_pos: [144 215 341 383 440 524 594 749 847 889]
#
# Line 52 (screen 6)
# text: un cuerpecito rosado y como translúcido (pensé en las
# spaces_pos: [144 187 341 440 468 538 706 805 847 903]
#
# Line 53 (screen 6)
# text: estatuillas chinas de cristal lechoso), semejante a
# spaces_pos: [144 313 411 454 566 706 847 875]
#
# Line 54 (screen 6)
# text: un pequeño lagarto de quince centímetros, terminado
# spaces_pos: [144 187 299 411 454 552 735 875]
#
# Line 55 (screen 6)
# text: en una cola de pez de una delicadeza extraordinaria,
# spaces_pos: [144 187 243 313 355 411 454 510 664 889]
#
# Line 56 (screen 6)
# text: la parte más sensible de nuestro cuerpo. Por el lomo
# spaces_pos: [144 187 271 327 454 496 608 721 777 819 889]
#
# Line 57 (screen 6)
# text: le corría una aleta transparente que se fusionaba con
# spaces_pos: [144 187 285 341 425 608 664 706 847 903]
#
# Line 58 (screen 6)
# text: la cola, pero lo que me obsesionó fueron las patas,
# spaces_pos: [144 187 271 341 383 440 482 622 721 777 875]
#
# Line 59 (screen 6)
# text: de una finura sutilísima, acabadas en menudos dedos,
# spaces_pos: [144 187 243 341 510 636 678 791 889]
#
# Line 60 (screen 7)
# text: en uñas minuciosamente humanas. Y entonces descubrí
# spaces_pos: [144 187 257 468 594 622 749 875]
#
# Line 61 (screen 7)
# text: sus ojos, su cara, dos orificios como cabezas de
# spaces_pos: [144 201 285 327 411 468 608 678 791 833]
#
# Line 62 (screen 7)
# text: alfiler, enteramente de un oro transparente carentes
# spaces_pos: [144 271 440 482 524 580 763 889]
#
# Line 63 (screen 7)
# text: de toda vida pero mirando, dejándose penetrar por mi
# spaces_pos: [144 187 257 327 397 524 664 791 847 889]
#
# Line 64 (screen 7)
# text: mirada que parecía pasar a través del punto áureo y
# spaces_pos: [144 243 299 411 496 524 622 678 763 847 875]
#
# Line 65 (screen 7)
# text: perderse en un diáfano misterio interior. Un
# spaces_pos: [144 271 313 355 468 594 735 777]
#
# Line 66 (screen 7)
# text: delgadísimo halo negro rodeaba el ojo y los inscribía
# spaces_pos: [144 313 383 468 580 622 678 706 763 903]
#
# Line 67 (screen 7)
# text: en la carne rosa, en la piedra rosa de la cabeza
# spaces_pos: [144 187 229 313 397 440 482 580 650 692 735 833]
#
# Line 68 (screen 7)
# text: vagamente triangular pero con lados curvos e
# spaces_pos: [144 285 440 510 566 650 749 777]
#
# Line 69 (screen 7)
# text: irregulares, que le daban una total semejanza con una
# spaces_pos: [144 327 383 425 510 566 650 791 847 903]
#
# Line 70 (screen 8)
# text: estatuilla corroída por el tiempo. La boca estaba
# spaces_pos: [144 299 425 482 524 636 678 749 847]
#
# Line 71 (screen 8)
# text: disimulada por el plano triangular de la cara, sólo
# spaces_pos: [144 299 355 397 482 636 678 721 805 875]
#
# Line 72 (screen 8)
# text: de perfil se adivinaba su tamaño considerable; de
# spaces_pos: [144 187 285 327 468 510 608 805 847]
#
# Line 73 (screen 8)
# text: frente una fina hendedura rasgaba apenas la piedra
# spaces_pos: [144 243 299 369 510 622 721 763 861]
#
# Line 74 (screen 8)
# text: sin vida. A ambos lados de la cabeza, donde hubieran
# spaces_pos: [144 201 285 313 397 482 524 566 678 763 889]
#
# Line 75 (screen 8)
# text: debido estar las orejas, le crecían tres ramitas
# spaces_pos: [144 243 327 383 496 538 650 721 833]
#
# Line 76 (screen 8)
# text: rojas como de coral, una excrescencia vegetal, las
# spaces_pos: [144 229 299 341 440 496 678 805 861]
#
# Line 77 (screen 8)
# text: branquias supongo. Y era lo único vivo en él, cada
# spaces_pos: [144 285 411 440 496 538 622 692 735 791 861]
#
# Line 78 (screen 8)
# text: diez o quince segundos las ramitas se enderezaban
# spaces_pos: [144 215 243 341 468 524 636 678 847]
#
# Line 79 (screen 8)
# text: rígidamente y volvían a bajarse. A veces una pata se
# spaces_pos: [144 313 341 454 482 608 636 721 777 847 889]
#
# Line 80 (screen 9)
# text: movía apenas, yo veía los diminutos dedos posándose
# spaces_pos: [144 229 341 383 454 510 650 735 875]
#
# Line 81 (screen 9)
# text: con suavidad en el musgo. Es que no nos gusta
# spaces_pos: [144 201 327 369 411 510 552 608 650 706 791]
#
# Line 82 (screen 9)
# text: movernos mucho, y el acuario es tan mezquino; apenas
# spaces_pos: [144 271 369 397 440 552 594 650 791 889]
#
# Line 83 (screen 9)
# text: avanzamos un poco nos damos con la cola o la cabeza
# spaces_pos: [144 285 327 397 454 538 594 636 706 735 777 875]
#
# Line 84 (screen 9)
# text: de otro de nosotros; surgen dificultades, peleas,
# spaces_pos: [144 187 257 299 440 538 735 847]
#
# Line 85 (screen 9)
# text: fatiga. El tiempo se siente menos si nos estamos
# spaces_pos: [144 257 299 397 440 538 622 664 721 833]
#
# Line 86 (screen 9)
# text: quietos.
# spaces_pos: [144 271]
#
# Line 87 (screen 9)
# text:    Fue su quietud la que me hizo inclinarme fascinado
# spaces_pos: [144 159 173 187 243 285 397 440 496 538 608 763 903]
#
# Line 88 (screen 9)
# text: la primera vez que vi a los axolotl. Oscuramente me
# spaces_pos: [144 187 299 355 411 454 482 538 664 833 875]
#
# Line 89 (screen 9)
# text: pareció comprender su voluntad secreta, abolir el
# spaces_pos: [144 257 411 454 580 706 805 847]
#
# Line 90 (screen 10)
# text: espacio y el tiempo con una inmovilidad indiferente.
# spaces_pos: [144 257 285 327 425 482 538 706 889]
#
# Line 91 (screen 10)
# text: Después supe mejor, la contracción de las branquias,
# spaces_pos: [144 257 327 425 468 636 678 735 889]
#
# Line 92 (screen 10)
# text: el tanteo de las finas patas en las piedras, la
# spaces_pos: [144 187 285 327 383 468 552 594 650 777 819]
#
# Line 93 (screen 10)
# text: repentina natación (algunos de ellos nadan con la
# spaces_pos: [144 285 411 538 580 664 749 805 847]
#
# Line 94 (screen 10)
# text: simple ondulación del cuerpo) me probó que eran
# spaces_pos: [144 243 397 454 566 608 692 749 819]
#
# Line 95 (screen 10)
# text: capaces de evadirse de ese sopor mineral en el que
# spaces_pos: [144 257 299 425 468 524 608 721 763 805 861]
#
# Line 96 (screen 10)
# text: pasaban horas enteras. Sus ojos sobre todo me
# spaces_pos: [144 257 341 468 524 594 678 749 791]
#
# Line 97 (screen 10)
# text: obsesionaban. Al lado de ellos en los restantes
# spaces_pos: [144 341 383 454 496 580 622 678 819]
#
# Line 98 (screen 10)
# text: acuarios, diversos peces me mostraban la simple
# spaces_pos: [144 285 411 496 538 678 721 819]
#
# Line 99 (screen 10)
# text: estupidez de sus hermosos ojos semejantes a los
# spaces_pos: [144 285 327 383 510 580 735 763 819]
#
# Line 100 (screen 11)
# text: nuestros. Los ojos de los axolotl me decían de la
# spaces_pos: [144 285 341 411 454 510 622 664 763 805 847]
#
# Line 101 (screen 11)
# text: presencia de una vida diferente, de otra manera de
# spaces_pos: [144 285 327 383 454 608 650 721 819 861]
#
# Line 102 (screen 11)
# text: mirar. Pegando mi cara al vidrio (a veces el guardián
# spaces_pos: [144 243 355 397 468 510 608 650 735 777 903]
#
# Line 103 (screen 11)
# text: tosía inquieto) buscaba ver mejor los diminutos
# spaces_pos: [144 229 369 482 538 622 678 819]
#
# Line 104 (screen 11)
# text: puntos áureos, esa entrada al mundo infinitamente
# spaces_pos: [144 243 355 411 524 566 650 847]
#
# Line 105 (screen 11)
# text: lento y remoto de las criaturas rosadas. Era inútil
# spaces_pos: [144 229 257 355 397 454 594 721 777 875]
#
# Line 106 (screen 11)
# text: golpear con el dedo en el cristal, delante de sus
# spaces_pos: [144 257 313 355 425 468 510 636 749 791 847]
#
# Line 107 (screen 11)
# text: caras no se advertía la menor reacción. Los ojos de
# spaces_pos: [144 229 271 313 440 482 566 706 763 833 875]
#
# Line 108 (screen 11)
# text: oro seguían ardiendo con su dulce, terrible luz;
# spaces_pos: [144 201 313 440 496 538 636 763 833]
#
# Line 109 (screen 11)
# text: seguían mirándome desde una profundidad insondable
# spaces_pos: [144 257 397 482 538 706 861]
#
# Line 110 (screen 12)
# text: que me daba vértigo.
# spaces_pos: [144 201 243 313 440]
#
# Line 111 (screen 12)
# text:    Y sin embargo estaban cerca. Lo supe antes de
# spaces_pos: [144 159 173 187 215 271 383 496 594 636 706 791 833]
#
# Line 112 (screen 12)
# text: esto, antes de ser un axolotl. Lo supe el día en que
# spaces_pos: [144 229 313 355 411 454 580 622 692 735 791 833 889]
#
# Line 113 (screen 12)
# text: me acerqué a ellos por primera vez. Los rasgos
# spaces_pos: [144 187 299 327 411 468 580 650 706 805]
#
# Line 114 (screen 12)
# text: antropomórficos de un mono revelan, al revés de lo
# spaces_pos: [144 369 411 454 524 650 692 777 819 861]
#
# Line 115 (screen 12)
# text: que cree la mayoría, la distancia que va de ellos a
# spaces_pos: [144 201 271 313 440 482 622 678 721 763 847 875]
#
# Line 116 (screen 12)
# text: nosotros. La absoluta falta de semejanza de los
# spaces_pos: [144 285 327 454 538 580 721 763 819]
#
# Line 117 (screen 12)
# text: axolotl con el ser humano me probó que mi
# spaces_pos: [144 257 313 355 411 510 552 636 692 735]
#
# Line 118 (screen 12)
# text: reconocimiento era válido, que no me apoyaba en
# spaces_pos: [144 355 411 524 580 622 664 777 819]
#
# Line 119 (screen 12)
# text: analogías fáciles. Sólo las manecitas... Pero una
# spaces_pos: [144 285 411 482 538 721 791 847]
#
# Line 120 (screen 13)
# text: lagartija tiene también manos así, y en nada se nos
# spaces_pos: [144 285 369 482 566 636 664 706 777 819 875]
#
# Line 121 (screen 13)
# text: parece. Yo creo que era la cabeza de los axolotl, esa
# spaces_pos: [144 257 299 369 425 482 524 622 664 721 847 903]
#
# Line 122 (screen 13)
# text: forma triangular rosada con los ojitos de oro. Eso
# spaces_pos: [144 229 383 482 538 594 692 735 805 861]
#
# Line 123 (screen 13)
# text: miraba y sabía. Eso reclamaba. No eran animales.
# spaces_pos: [144 243 271 369 425 580 622 692 833]
#
# Line 124 (screen 13)
# text:    Parecía fácil, casi obvio, caer en la mitología.
# spaces_pos: [144 159 173 187 299 397 468 566 636 678 721 875]
#
# Line 125 (screen 13)
# text: Empecé viendo en los axolotl una metamorfosis que no
# spaces_pos: [144 243 341 383 440 552 608 791 847 889]
#
# Line 126 (screen 13)
# text: conseguía anular una misteriosa humanidad. Los
# spaces_pos: [144 285 383 440 594 749 805]
#
# Line 127 (screen 13)
# text: imaginé conscientes, esclavos de su cuerpo,
# spaces_pos: [144 257 440 566 608 650 763]
#
# Line 128 (screen 13)
# text: infinitamente condenados a un silencio abisal, a una
# spaces_pos: [144 341 496 524 566 692 805 833 889]
#
# Line 129 (screen 13)
# text: reflexión desesperada. Su mirada ciega, el diminuto
# spaces_pos: [144 285 468 510 608 706 749 875]
#
# Line 130 (screen 14)
# text: disco de oro inexpresivo y sin embargo terriblemente
# spaces_pos: [144 229 271 327 496 524 580 692 889]
#
# Line 131 (screen 14)
# text: lúcido, me penetraba como un mensaje: "Sálvanos,
# spaces_pos: [144 257 299 440 510 552 678 833]
#
# Line 132 (screen 14)
# text: sálvanos". Me sorprendía musitando palabras de
# spaces_pos: [144 299 341 496 636 763 805]
#
# Line 133 (screen 14)
# text: consuelo, transmitiendo pueriles esperanzas. Ellos
# spaces_pos: [144 285 482 608 777 861]
#
# Line 134 (screen 14)
# text: seguían mirándome inmóviles; de pronto las ramillas
# spaces_pos: [144 257 397 552 594 692 749 875]
#
# Line 135 (screen 14)
# text: rosadas de las branquias se enderezaban. En ese
# spaces_pos: [144 257 299 355 496 538 721 763 819]
#
# Line 136 (screen 14)
# text: instante yo sentía como un dolor sordo; tal vez me
# spaces_pos: [144 271 313 411 482 524 608 706 763 819 861]
#
# Line 137 (screen 14)
# text: veían, captaban mi esfuerzo por penetrar en lo
# spaces_pos: [144 243 369 411 538 594 721 763 805]
#
# Line 138 (screen 14)
# text: impenetrable de sus vidas. No eran seres humanos,
# spaces_pos: [144 327 369 425 524 566 636 721 847]
#
# Line 139 (screen 14)
# text: pero en ningún animal había encontrado una relación
# spaces_pos: [144 215 257 355 454 538 692 749 875]
#
# Line 140 (screen 15)
# text: tan profunda conmigo. Los axolotl eran como testigos
# spaces_pos: [144 201 327 454 510 622 692 763 889]
#
# Line 141 (screen 15)
# text: de algo, y a veces como horribles jueces. Me sentía
# spaces_pos: [144 187 271 299 327 411 482 622 735 777 875]
#
# Line 142 (screen 15)
# text: innoble frente a ellos, había una pureza tan
# spaces_pos: [144 257 355 383 482 566 622 721 777]
#
# Line 143 (screen 15)
# text: espantosa en esos ojos transparentes. Eran larvas,
# spaces_pos: [144 285 327 397 468 678 749 861]
#
# Line 144 (screen 15)
# text: pero larva quiere decir máscara y también fantasma.
# spaces_pos: [144 215 299 397 482 594 622 735 875]
#
# Line 145 (screen 15)
# text: Detrás de esas caras aztecas inexpresivas y sin
# spaces_pos: [144 243 285 355 440 552 735 763 819]
#
# Line 146 (screen 15)
# text: embargo de una crueldad implacable, ¿qué imagen
# spaces_pos: [144 257 299 355 482 650 721 819]
#
# Line 147 (screen 15)
# text: esperaba su hora?
# spaces_pos: [144 271 313 397]
#
# Line 148 (screen 15)
# text:    Les temía. Creo que de no haber sentido la
# spaces_pos: [144 159 173 187 243 341 411 468 510 552 636 749 791]
#
# Line 149 (screen 15)
# text: proximidad de otros visitantes y del guardián, no me
# spaces_pos: [144 299 341 425 580 608 664 805 847 889]
#
# Line 150 (screen 16)
# text: hubiese atrevido a quedarme solo con ellos. "Usted se
# spaces_pos: [144 257 383 411 538 608 664 763 861 903]
#
# Line 151 (screen 16)
# text: los come con los ojos", me decía riendo el guardián,
# spaces_pos: [144 201 271 327 383 482 524 608 706 749 889]
#
# Line 152 (screen 16)
# text: que debía suponerme un poco desequilibrado. No se
# spaces_pos: [144 201 285 425 468 538 763 805 847]
#
# Line 153 (screen 16)
# text: daba cuenta de que eran ellos los que me devoraban
# spaces_pos: [144 215 313 355 411 482 566 622 678 721 861]
#
# Line 154 (screen 16)
# text: lentamente por los ojos en un canibalismo de oro.
# spaces_pos: [144 299 355 411 482 524 566 735 777 847]
#
# Line 155 (screen 16)
# text: Lejos del acuario no hacía más que pensar en ellos,
# spaces_pos: [144 229 285 397 440 524 580 636 735 777 875]
#
# Line 156 (screen 16)
# text: era como si me influyeran a distancia. Llegué a ir
# spaces_pos: [144 201 271 313 355 510 538 692 791 819 861]
#
# Line 157 (screen 16)
# text: todos los días, y de noche los imaginaba inmóviles en
# spaces_pos: [144 229 285 369 397 440 524 580 721 861 903]
#
# Line 158 (screen 16)
# text: la oscuridad, adelantando lentamente una mano que de
# spaces_pos: [144 187 341 510 664 721 791 847 889]
#
# Line 159 (screen 16)
# text: pronto encontraba la de otro. Acaso sus ojos veían en
# spaces_pos: [144 243 397 440 482 566 650 706 777 861 903]
#
# Line 160 (screen 17)
# text: plena noche, y el día continuaba para ellos
# spaces_pos: [144 229 327 355 397 454 608 678 763]
#
# Line 161 (screen 17)
# text: indefinidamente. Los ojos de los axolotl no tienen
# spaces_pos: [144 383 440 510 552 608 721 763 861]
#
# Line 162 (screen 17)
# text: párpados.
# spaces_pos: [144 285]
#
# Line 163 (screen 17)
# text:    Ahora sé que no hubo nada de extraño, que eso
# spaces_pos: [144 159 173 187 271 313 369 411 482 552 594 721 777 833]
#
# Line 164 (screen 17)
# text: tenía que ocurrir. Cada mañana al inclinarme sobre el
# spaces_pos: [144 229 285 411 482 580 622 777 861 903]
#
# Line 165 (screen 17)
# text: acuario el reconocimiento era mayor. Sufrían, cada
# spaces_pos: [144 257 299 510 566 664 791 861]
#
# Line 166 (screen 17)
# text: fibra de mi cuerpo alcanzaba ese sufrimiento
# spaces_pos: [144 229 271 313 411 552 608 777]
#
# Line 167 (screen 17)
# text: amordazado, esa tortura rígida en el fondo del agua.
# spaces_pos: [144 313 369 482 580 622 664 749 805 889]
#
# Line 168 (screen 17)
# text: Espiaban algo, un remoto señorío aniquilado, un
# spaces_pos: [144 271 355 397 496 608 777 819]
#
# Line 169 (screen 17)
# text: tiempo de libertad en que el mundo había sido de los
# spaces_pos: [144 243 285 411 454 510 552 636 721 791 833 889]
#
# Line 170 (screen 18)
# text: axolotl. No era posible que una expresión tan
# spaces_pos: [144 271 313 369 482 538 594 735 791]
#
# Line 171 (screen 18)
# text: terrible que alcanzaba a vencer la inexpresividad
# spaces_pos: [144 271 327 468 496 594 636 847]
#
# Line 172 (screen 18)
# text: forzada de sus rostros de piedra, no portara un
# spaces_pos: [144 257 299 355 468 510 622 664 777 819]
#
# Line 173 (screen 18)
# text: mensaje de dolor, la prueba de esa condena eterna, de
# spaces_pos: [144 257 299 397 440 538 580 636 749 861 903]
#
# Line 174 (screen 18)
# text: ese infierno líquido que padecían. Inútilmente quería
# spaces_pos: [144 201 327 440 496 636 805 903]
#
# Line 175 (screen 18)
# text: probarme que mi propia sensibilidad proyectaba en los
# spaces_pos: [144 271 327 369 468 650 805 847 903]
#
# Line 176 (screen 18)
# text: axolotl una conciencia inexistente. Ellos y yo
# spaces_pos: [144 257 313 468 650 735 763 805]
#
# Line 177 (screen 18)
# text: sabíamos. Por eso no hubo nada de extraño en lo que
# spaces_pos: [144 285 341 397 440 510 580 622 735 777 819 875]
#
# Line 178 (screen 18)
# text: ocurrió. Mi cara estaba pegada al vidrio del acuario,
# spaces_pos: [144 271 313 383 482 580 622 721 777 903]
#
# Line 179 (screen 18)
# text: mis ojos trataban una vez mas de penetrar el misterio
# spaces_pos: [144 201 271 397 454 510 566 608 735 777 903]
#
# Line 180 (screen 19)
# text: de esos ojos de oro sin iris y sin pupila. Veía de
# spaces_pos: [144 187 257 327 369 425 482 552 580 636 749 819 861]
#
# Line 181 (screen 19)
# text: muy cerca la cara de un axolotl inmóvil junto al
# spaces_pos: [144 201 285 327 397 440 482 594 706 791 833]
#
# Line 182 (screen 19)
# text: vidrio. Sin transición, sin sorpresa, vi mi cara
# spaces_pos: [144 257 313 482 538 678 721 763 833]
#
# Line 183 (screen 19)
# text: contra el vidrio, en vez del axolotl vi mi cara
# spaces_pos: [144 243 285 397 440 496 552 664 706 749 819]
#
# Line 184 (screen 19)
# text: contra el vidrio, la vi fuera del acuario, la vi del
# spaces_pos: [144 243 285 397 440 482 566 622 749 791 833 889]
#
# Line 185 (screen 19)
# text: otro lado del vidrio. Entonces mi cara se apartó y yo
# spaces_pos: [144 215 285 341 454 580 622 692 735 833 861 903]
#
# Line 186 (screen 19)
# text: comprendí.
# spaces_pos: [144 299]
#
# Line 187 (screen 19)
# text:    Sólo una cosa era extraña: seguir pensando como
# spaces_pos: [144 159 173 187 257 313 383 440 566 664 791 861]
#
# Line 188 (screen 19)
# text: antes, saber. Darme cuenta de eso fue en el primer
# spaces_pos: [144 243 341 425 524 566 622 678 721 763 861]
#
# Line 189 (screen 19)
# text: momento como el horror del enterrado vivo que
# spaces_pos: [144 257 327 369 468 524 664 735 791]
#
# Line 190 (screen 20)
# text: despierta a su destino. Afuera mi cara volvía a
# spaces_pos: [144 285 313 355 482 580 622 692 791 819]
#
# Line 191 (screen 20)
# text: acercarse al vidrio, veía mi boca de labios apretados
# spaces_pos: [144 285 327 440 510 552 622 664 763 903]
#
# Line 192 (screen 20)
# text: por el esfuerzo de comprender a los axolotl. Yo era
# spaces_pos: [144 201 243 369 411 566 594 650 777 819 875]
#
# Line 193 (screen 20)
# text: un axolotl y sabía ahora instantáneamente que ninguna
# spaces_pos: [144 187 299 327 411 496 735 791 903]
#
# Line 194 (screen 20)
# text: comprensión era posible. Él estaba fuera del acuario,
# spaces_pos: [144 313 369 496 538 636 721 777 903]
#
# Line 195 (screen 20)
# text: su pensamiento era un pensamiento fuera del acuario.
# spaces_pos: [144 187 355 411 454 622 706 763 889]
#
# Line 196 (screen 20)
# text: Conociéndolo, siendo él mismo, yo era un axolotl y
# spaces_pos: [144 341 440 482 580 622 678 721 833 861]
#
# Line 197 (screen 20)
# text: estaba en mi mundo. El horror venía -lo supe en el
# spaces_pos: [144 243 285 327 425 468 566 650 706 777 819 861]
#
# Line 198 (screen 20)
# text: mismo momento- de creerme prisionero en un cuerpo de
# spaces_pos: [144 229 355 397 510 664 706 749 847 889]
#
# Line 199 (screen 20)
# text: axolotl, transmigrado a él con mi pensamiento de
# spaces_pos: [144 271 454 482 524 580 622 791 833]
#
# Line 200 (screen 21)
# text: hombre, enterrado vivo en un axolotl, condenado a
# spaces_pos: [144 257 397 468 510 552 678 819 847]
#
# Line 201 (screen 21)
# text: moverme lúcidamente entre criaturas insensibles. Pero
# spaces_pos: [144 257 425 510 650 833 903]
#
# Line 202 (screen 21)
# text: aquello cesó cuando una pata vino a rozarme la cara,
# spaces_pos: [144 257 327 425 482 552 622 650 763 805 889]
#
# Line 203 (screen 21)
# text: cuando moviéndome apenas a un lado vi a un axolotl
# spaces_pos: [144 243 397 496 524 566 636 678 706 749 861]
#
# Line 204 (screen 21)
# text: junto a mí que me miraba, y supe que también él
# spaces_pos: [144 229 257 299 355 397 510 538 608 664 777 819]
#
# Line 205 (screen 21)
# text: sabía, sin comunicación posible pero tan claramente.
# spaces_pos: [144 243 299 482 594 664 721 889]
#
# Line 206 (screen 21)
# text: O yo estaba también en él, o todos nosotros
# spaces_pos: [144 173 215 313 425 468 524 552 636 763]
#
# Line 207 (screen 21)
# text: pensábamos como un hombre, incapaces de expresión,
# spaces_pos: [144 299 369 411 524 664 706 861]
#
# Line 208 (screen 21)
# text: limitados al resplandor dorado de nuestros ojos que
# spaces_pos: [144 285 327 482 580 622 749 819 875]
#
# Line 209 (screen 21)
# text: miraban la cara del hombre pegada al acuario.
# spaces_pos: [144 257 299 369 425 524 622 664 791]
#
# Line 210 (screen 22)
# text: Él volvió muchas veces, pero viene menos ahora. Pasa
# spaces_pos: [144 187 285 383 482 552 636 721 819 889]
#
# Line 211 (screen 22)
# text: semanas sin asomarse. Ayer lo vi, me miró largo rato
# spaces_pos: [144 257 313 454 524 566 622 664 735 819 889]
#
# Line 212 (screen 22)
# text: y se fue bruscamente. Me pareció que no se interesaba
# spaces_pos: [144 173 215 271 454 496 608 664 706 749 903]
#
# Line 213 (screen 22)
# text: tanto por nosotros, que obedecía a una costumbre.
# spaces_pos: [144 229 285 425 482 608 636 692 847]
#
# Line 214 (screen 22)
# text: Como lo único que hago es pensar, pude pensar mucho
# spaces_pos: [144 215 257 341 397 468 510 622 692 791 875]
#
# Line 215 (screen 22)
# text: en él. Se me ocurre que al principio continuamos
# spaces_pos: [144 187 243 285 327 425 482 524 664 833]
#
# Line 216 (screen 22)
# text: comunicados, que él se sentía más que nunca unido al
# spaces_pos: [144 327 383 425 468 566 622 678 763 847 889]
#
# Line 217 (screen 22)
# text: misterio que lo obsesionaba. Pero los puentes están
# spaces_pos: [144 271 327 369 552 622 678 791 875]
#
# Line 218 (screen 22)
# text: cortados entre él y yo porque lo que era su obsesión
# spaces_pos: [144 271 355 397 425 468 566 608 664 721 763 889]
#
# Line 219 (screen 22)
# text: es ahora un axolotl, ajeno a su vida de hombre. Creo
# spaces_pos: [144 187 271 313 440 524 552 594 664 706 819 889]
#
# Line 220 (screen 23)
# text: que al principio yo era capaz de volver en cierto
# spaces_pos: [144 201 243 383 425 482 566 608 706 749 847]
#
# Line 221 (screen 23)
# text: modo a él -ah, sólo en cierto modo-, y mantener
# spaces_pos: [144 215 243 285 355 425 468 566 664 692 819]
#
# Line 222 (screen 23)
# text: alerta su deseo de conocernos mejor. Ahora soy
# spaces_pos: [144 243 285 369 411 566 664 749 805]
#
# Line 223 (screen 23)
# text: definitivamente un axolotl, y si pienso como un
# spaces_pos: [144 369 411 538 566 608 706 777 819]
#
# Line 224 (screen 23)
# text: hombre es sólo porque todo axolotl piensa como un
# spaces_pos: [144 243 285 355 454 524 636 735 805 847]
#
# Line 225 (screen 23)
# text: hombre dentro de su imagen de piedra rosa. Me parece
# spaces_pos: [144 243 341 383 425 524 566 664 749 791 889]
#
# Line 226 (screen 23)
# text: que de todo esto alcancé a comunicarle algo en los
# spaces_pos: [144 201 243 313 383 496 524 692 763 805 861]
#
# Line 227 (screen 23)
# text: primeros días, cuando yo era todavía él. Y en esta
# spaces_pos: [144 271 355 454 496 552 664 721 749 791 861]
#
# Line 228 (screen 23)
# text: soledad final, a la que él ya no vuelve, me consuela
# spaces_pos: [144 257 355 383 425 482 524 566 608 721 763 889]
#
# Line 229 (screen 23)
# text: pensar que acaso va a escribir sobre nosotros,
# spaces_pos: [144 243 299 383 425 454 580 664 805]
#
# Line 230 (screen 24)
# text: creyendo imaginar un cuento va a escribir todo esto
# spaces_pos: [144 271 397 440 538 580 608 735 805 875]
#
# Line 231 (screen 24)
# text: sobre los axolotl.
# spaces_pos: [144 229 285 411]

# %%
from pathlib import Path
from scipy.io import loadmat
import pandas as pd
import json

def first_subject_with_stimulus(trials_root, item):
    trials_root = Path(trials_root)
    for subj_dir in sorted(trials_root.iterdir()):
        item_dir = subj_dir / item
        if item_dir.is_dir() and any(item_dir.rglob("lines.pkl")):
            return item_dir
    return None

def stimuli_to_json(item, stimuli_path="stimuli", trials_root="data/processed/trials"):
    mat = loadmat(f"{stimuli_path}/{item}.mat", simplify_cells=True)
    lines = mat["lines"]

    screens = {}
    for line in lines:
        screen_id = int(line["screen"])
        screens.setdefault(screen_id, []).append(line)

    item_trial_path = first_subject_with_stimulus(trials_root, item)

    out = []
    global_index = 0
    for screen_id in sorted(screens.keys()):
        words_list = []
        screen_word_index = 0

        y_bounds = None
        if item_trial_path:
            lines_pkl = Path(item_trial_path) / f"screen_{screen_id}" / "lines.pkl"
            if lines_pkl.exists():
                y_bounds = pd.read_pickle(lines_pkl)["y"].to_numpy()

        for line_idx, line in enumerate(screens[screen_id]):
            words = line["text"].split()
            spaces_pos = line["spaces_pos"]

            y = None
            if y_bounds is not None and line_idx + 1 < len(y_bounds):
                y = (y_bounds[line_idx] + y_bounds[line_idx + 1]) / 2

            for i, word in enumerate(words):
                x = (spaces_pos[i] + spaces_pos[i + 1]) / 2
                words_list.append({
                    "word": word,
                    "x": float(x),
                    "y": None if y is None else float(y),
                    "line": line_idx,
                    "index": global_index,
                    "screen_word_index": screen_word_index
                })
                global_index += 1
                screen_word_index += 1

        out.append({
            "screen_index": screen_id - 1,
            "words": words_list
        })

    return out

def build_all_stimuli_combined(stimuli_path="stimuli", trials_root="data/processed/trials", out_file="all_stimuli.json"):
    stimuli_path = Path(stimuli_path)
    all_data = {}

    for mat_file in sorted(stimuli_path.glob("*.mat")):
        item = mat_file.stem
        all_data[item] = stimuli_to_json(item, stimuli_path=stimuli_path, trials_root=trials_root)
        print(f"processed {item}")

    with open(out_file, "w", encoding="utf-8") as f:
        json.dump(all_data, f, ensure_ascii=False, indent=2)

# %%
build_all_stimuli_combined(stimuli_path = '../data/stimuli', trials_root='../data/processed_all_humans/trials', out_file="all_stimuli.json")
# Out:
# processed Ahora debería reírme, si no estuviera muerto
# processed Axolotl
# processed Bienvenido Bob
# processed Buenos Aires
# processed Carta a una señorita en París
# processed Carta abierta
# processed Cómo funciona caminar en la nieve
# processed Cómo funcionan los bolsillos
# processed Educar para escalar y bucear
# processed El almohadón de plumas
# processed El espejo
# processed El golpe de gracia
# processed El loco cansino
# processed El negro de París
# processed El origen de las especies
# processed Embarrar la magia
# processed La canción que cantábamos todos los días
# processed La de la Obsesión por la Patineta
# processed La gallina degollada
# processed La lluvia de fuego
# processed La máscara de la Muerte Roja
# processed La noche de los feos
# processed La salud de los enfermos
# processed Las fotografías
# processed Rebeca
# processed Rubí y el lago danzante
# processed Sombras sobre vidrio esmerilado 1
# processed Sombras sobre vidrio esmerilado 2
# processed Test
# processed Una rosa para Emilia
# processed Wakefield

# %%
import json

with open("all_stimuli.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# see stimuli names
print("Number of stimuli:", len(data))
print("Some stimuli:", list(data.keys())[:5])

# inspect one stimuli
item = list(data.keys())[0]
print("Inspecting item:", item)
print("Number of screens:", len(data[item]))
print("First screen data:", data[item][0])  # first screen dict

# inspect first word entry of first screen
print("First word entry of first screen:", data[item][0]["words"][0])

# pretty-print a small slice
#import pprint
#pprint.pprint(data[item][0]["words"][:5])
# Out:
# Number of stimuli: 31
# Some stimuli: ['Ahora debería reírme, si no estuviera muerto', 'Axolotl', 'Bienvenido Bob', 'Buenos Aires', 'Carta a una señorita en París']
# Inspecting item: Ahora debería reírme, si no estuviera muerto
# Number of screens: 4
# First screen data: {'screen_index': 0, 'words': [{'word': 'Una', 'x': 304.0, 'y': 173.43839835728954, 'line': 0, 'index': 0, 'screen_word_index': 0}, {'word': 'vez', 'x': 360.0, 'y': 173.43839835728954, 'line': 0, 'index': 1, 'screen_word_index': 1}, {'word': 'hubo', 'x': 423.0, 'y': 173.43839835728954, 'line': 0, 'index': 2, 'screen_word_index': 2}, {'word': 'dos', 'x': 486.0, 'y': 173.43839835728954, 'line': 0, 'index': 3, 'screen_word_index': 3}, {'word': 'mujeres', 'x': 570.0, 'y': 173.43839835728954, 'line': 0, 'index': 4, 'screen_word_index': 4}, {'word': 'casadas', 'x': 682.0, 'y': 173.43839835728954, 'line': 0, 'index': 5, 'screen_word_index': 5}, {'word': 'que', 'x': 766.0, 'y': 173.43839835728954, 'line': 0, 'index': 6, 'screen_word_index': 6}, {'word': 'se', 'x': 815.0, 'y': 173.43839835728954, 'line': 0, 'index': 7, 'screen_word_index': 7}, {'word': 'trenzaron', 'x': 906.0, 'y': 173.43839835728954, 'line': 0, 'index': 8, 'screen_word_index': 8}, {'word': 'en', 'x': 997.0, 'y': 173.43839835728954, 'line': 0, 'index': 9, 'screen_word_index': 9}, {'word': 'una', 'x': 1046.0, 'y': 173.43839835728954, 'line': 0, 'index': 10, 'screen_word_index': 10}, {'word': 'disputa', 'x': 1130.0, 'y': 173.43839835728954, 'line': 0, 'index': 11, 'screen_word_index': 11}, {'word': 'para', 'x': 1221.0, 'y': 173.43839835728954, 'line': 0, 'index': 12, 'screen_word_index': 12}, {'word': 'ver', 'x': 1284.0, 'y': 173.43839835728954, 'line': 0, 'index': 13, 'screen_word_index': 13}, {'word': 'cuál', 'x': 1347.0, 'y': 173.43839835728954, 'line': 0, 'index': 14, 'screen_word_index': 14}, {'word': 'de', 'x': 1403.0, 'y': 173.43839835728954, 'line': 0, 'index': 15, 'screen_word_index': 15}, {'word': 'las', 'x': 1452.0, 'y': 173.43839835728954, 'line': 0, 'index': 16, 'screen_word_index': 16}, {'word': 'dos', 'x': 1508.0, 'y': 173.43839835728954, 'line': 0, 'index': 17, 'screen_word_index': 17}, {'word': 'tenía', 'x': 1578.0, 'y': 173.43839835728954, 'line': 0, 'index': 18, 'screen_word_index': 18}, {'word': 'un', 'x': 297.0, 'y': 242.03798767967152, 'line': 1, 'index': 19, 'screen_word_index': 19}, {'word': 'marido', 'x': 367.0, 'y': 242.03798767967152, 'line': 1, 'index': 20, 'screen_word_index': 20}, {'word': 'más', 'x': 444.0, 'y': 242.03798767967152, 'line': 1, 'index': 21, 'screen_word_index': 21}, {'word': 'imbécil.', 'x': 535.0, 'y': 242.03798767967152, 'line': 1, 'index': 22, 'screen_word_index': 22}, {'word': 'Como', 'x': 633.0, 'y': 242.03798767967152, 'line': 1, 'index': 23, 'screen_word_index': 23}, {'word': 'no', 'x': 689.0, 'y': 242.03798767967152, 'line': 1, 'index': 24, 'screen_word_index': 24}, {'word': 'llegaban', 'x': 773.0, 'y': 242.03798767967152, 'line': 1, 'index': 25, 'screen_word_index': 25}, {'word': 'a', 'x': 850.0, 'y': 242.03798767967152, 'line': 1, 'index': 26, 'screen_word_index': 26}, {'word': 'ponerse', 'x': 920.0, 'y': 242.03798767967152, 'line': 1, 'index': 27, 'screen_word_index': 27}, {'word': 'de', 'x': 997.0, 'y': 242.03798767967152, 'line': 1, 'index': 28, 'screen_word_index': 28}, {'word': 'acuerdo,', 'x': 1081.0, 'y': 242.03798767967152, 'line': 1, 'index': 29, 'screen_word_index': 29}, {'word': 'al', 'x': 1165.0, 'y': 242.03798767967152, 'line': 1, 'index': 30, 'screen_word_index': 30}, {'word': 'final', 'x': 1228.0, 'y': 242.03798767967152, 'line': 1, 'index': 31, 'screen_word_index': 31}, {'word': 'decidieron', 'x': 1347.0, 'y': 242.03798767967152, 'line': 1, 'index': 32, 'screen_word_index': 32}, {'word': 'que', 'x': 1452.0, 'y': 242.03798767967152, 'line': 1, 'index': 33, 'screen_word_index': 33}, {'word': 'los', 'x': 1508.0, 'y': 242.03798767967152, 'line': 1, 'index': 34, 'screen_word_index': 34}, {'word': 'pondrían', 'x': 339.0, 'y': 298.2186858316222, 'line': 2, 'index': 35, 'screen_word_index': 35}, {'word': 'a', 'x': 416.0, 'y': 298.2186858316222, 'line': 2, 'index': 36, 'screen_word_index': 36}, {'word': 'prueba', 'x': 479.0, 'y': 298.2186858316222, 'line': 2, 'index': 37, 'screen_word_index' ...
# First word entry of first screen: {'word': 'Una', 'x': 304.0, 'y': 173.43839835728954, 'line': 0, 'index': 0, 'screen_word_index': 0}

# %%
list(data.keys())[:5]
# Out:
# []
