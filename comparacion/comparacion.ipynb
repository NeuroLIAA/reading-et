# %%
import pandas as pd

# Read a TSV file into a pandas DataFrame (new Jupyter cell)

# set this to your TSV path (or a Path object)
tsv_path_1 = "el_espejo_screens_con_enter.tsv"
tsv_path_2 = "el_espejo_screens_sin_enter.tsv"

# read TSV; adjust options (parse_dates, usecols, dtype, encoding) as needed
df_1 = pd.read_csv(tsv_path_1, sep="\t", encoding="utf-8", na_values=["", "NA"])
df_2 = pd.read_csv(tsv_path_2, sep="\t", encoding="utf-8", na_values=["", "NA"])

# %%
# show all columns when displaying DataFrames
pd.set_option('display.max_columns', None)

# display (example)
df_1.shape
# Out:
# (836, 22)

# %%
df_1.head()
# Out:
#    fixation_counter  text_id  simulation_id foveal_word  foveal_word_index  \
# 0                 0        0              0       nunca                  0
# 1                 1        0              0     pasaron                  2
# 2                 2        0              0          me                  1
# 3                 3        0              0       cosas                  3
# 4                 4        0              0       raras                  4
#
#    foveal_word_frequency  foveal_word_predictability  foveal_word_length  \
# 0               4.725438                           0                   5
# 1               3.059942                           0                   7
# 2               5.612029                           0                   2
# 3               4.647862                           0                   5
# 4               2.753583                           0                   5
#
#    foveal_word_threshold                        stimulus  \
# ...

# %%
df_2.shape
# Out:
# (851, 22)

# %%
words_df_1 = df_1['foveal_word']
words_df_2 = df_2['foveal_word']

for i in range(min(len(words_df_1), len(words_df_2))):
    if words_df_1[i] != words_df_2[i]:
        print(f"Difference at index {i}: df_1 has '{words_df_1[i]}', df_2 has '{words_df_2[i]}'")
# Out:
# Difference at index 107: df_1 has 'de', df_2 has 'vida'
# Difference at index 110: df_1 has 'vida', df_2 has 'y'
# Difference at index 111: df_1 has 'y', df_2 has 'de'
# Difference at index 112: df_1 has 'uno', df_2 has 'trabajos'
# Difference at index 113: df_1 has 'los', df_2 has 'trabajos'
# Difference at index 114: df_1 has 'trabajos', df_2 has 'tuve'
# Difference at index 115: df_1 has 'trabajos', df_2 has 'guardia'
# Difference at index 116: df_1 has 'tuve', df_2 has 'como'
# Difference at index 117: df_1 has 'guardia', df_2 has 'fue'
# Difference at index 118: df_1 has 'como', df_2 has 'nocturno'
# Difference at index 119: df_1 has 'fue', df_2 has 'nocturno'
# Difference at index 120: df_1 has 'nocturno', df_2 has 'secundaria'
# Difference at index 121: df_1 has 'nocturno', df_2 has 'una'
# Difference at index 122: df_1 has 'secundaria', df_2 has 'en'
# Difference at index 123: df_1 has 'una', df_2 has 'secundaria'
# Difference at index 124: df_1 has 'en', df_2 has 'tarea'
# ...

# %%
for idx,
# Out:
#     fixation_counter  text_id  simulation_id    foveal_word  \
# 0                  0        0              0          nunca
# 1                  1        0              0        pasaron
# 2                  2        0              0             me
# 3                  3        0              0          cosas
# 4                  4        0              0          raras
# 5                  5        0              0        refiero
# 6                  6        0              0             me
# 7                  7        0              0      historias
# 8                  8        0              0      historias
# 9                  9        0              0      fantasmas
# 10                10        0              0             de
# 11                11        0              0             de
# 12                12        0              0             de
# 13                13        0              0              o
# 14                14        0              0             de
# ...
